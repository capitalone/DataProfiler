# %% [markdown]
# # Unstructured Profilers

# %% [markdown]
# **Data profiling** - *is the process of examining a dataset and collecting statistical or informational summaries about said dataset.*
#
# The Profiler class inside the DataProfiler is designed to generate *data profiles* via the Profiler class, which ingests either a Data class or a Pandas DataFrame.
#
# Currently, the Data class supports loading the following file formats:
#
# * Any delimited  (CSV, TSV, etc.)
# * JSON object
# * Avro
# * Parquet
# * Text files
#
# Once the data is loaded, the Profiler can calculate statistics and predict the entities (via the Labeler) of every column (csv) or key-value (JSON) store as well as dataset wide information, such as the number of nulls, duplicates, etc.
#
# This example will look at specifically the unstructured data types for unstructured profiling. This means that only text files, lists of strings, single column pandas dataframes/series, or DataProfile Data objects in string format will work with the unstructured profiler.

# %% [markdown]
# ## Reporting

# %% [markdown]
# One of the primary purposes of the Profiler are to quickly identify what is in the dataset. This can be useful for analyzing a dataset prior to use or determining which columns could be useful for a given purpose.
#
# In terms of reporting, there are multiple reporting options:
#
# * **Pretty**: Floats are rounded to four decimal places, and lists are shortened.
# * **Compact**: Similar to pretty, but removes detailed statistics
# * **Serializable**: Output is json serializable and not prettified
# * **Flat**: Nested Output is returned as a flattened dictionary
#
# The **Pretty** and **Compact** reports are the two most commonly used reports and includes `global_stats` and `data_stats` for the given dataset. `global_stats` contains overall properties of the data such as samples used and file encoding. `data_stats` contains specific properties and statistics for each text sample.
#
# For unstructured profiles, the report looks like this:
#
# ```
# "global_stats": {
#     "samples_used": int,
#     "empty_line_count": int,
#     "file_type": string,
#     "encoding": string
# },
# "data_stats": {
#     "data_label": {
#         "entity_counts": {
#             "word_level": dict(int),
#             "true_char_level": dict(int),
#             "postprocess_char_level": dict(int)
#         },
#         "times": dict(float)
#     },
#     "statistics": {
#         "vocab": list(char),
#         "words": list(string),
#         "word_count": dict(int),
#         "times": dict(float)
#     }
# }
# ```

# %%
import os
import sys
import json
sys.path.insert(0, '..')
import dataprofiler as dp

data_path = "../dataprofiler/tests/data"

# %%
data = dp.Data(os.path.join(data_path, "txt/discussion_reddit.txt"))
profile = dp.Profiler(data)

report  = profile.report(report_options={"output_format": "pretty"})
print(json.dumps(report, indent=4))
# Out:
# Finding the empty lines in the data...
# Calculating the statistics...
# {
#     "global_stats": {
#         "samples_used": 1,
#         "empty_line_count": 0,
#         "file_type": "text",
#         "encoding": "utf-8"
#     },
#     "data_stats": {
#         "data_label": {
#             "entity_counts": {
#                 "word_level": {
#                     "UNKNOWN": 14017,
#                     "INTEGER": 65,
#                     "ORDINAL": 30,
#                     "QUANTITY": 28,
#                     "PERSON": 25,
#                     "ADDRESS": 6,
#                     "DATE": 10,
#                     "US_STATE": 4,
#                     "BAN": 3,
#                     "URL": 10,
#                     "EMAIL_ADDRESS": 2,
#                     "IPV6": 1,
#                     "FLOAT": 1,
#                     "DRIVERS_LICENSE": 3,
#                     "HASH_OR_KEY": 1
#                 },
#                 "true_char_level": {
#                     "UNKNOWN": 78601,
#                     "INTEGER": 580,
#                     "ORDINAL": 158,
#                     "QUANTITY": 644,
#                     "PERSON": 298,
#                     "ADDRESS": 73,
#                     "MAC_ADDRESS": 1,
#                     "DATE": 86,
#                     "US_STATE": 21,
#                     "FLOAT": 11,
#                     "BAN": 31,
#                     "URL": 318,
#                     "EMAIL_ADDRESS": 33,
#                     "DRIVERS_LICENSE": 23,
#                     "HASH_OR_KEY": 24,
#                     "IPV6": 10,
#                     "PAD": 1
#                 },
#                 "postprocess_char_level": {
#                     "UNKNOWN": 79801,
#                     "INTEGER": 153,
#                     "ORDINAL": 74,
#                     "QUANTITY": 172,
#                     "PERSON": 263,
#                     "ADDRESS": 47,
#                     "DATE": 67,
#                     "US_STATE": 17,
#                     "BAN": 30,
#                     "URL": 200,
#                     "EMAIL_ADDRESS": 33,
#                     "IPV6": 5,
#                     "FLOAT": 6,
#                     "DRIVERS_LICENSE": 22,
#                     "HASH_OR_KEY": 23
#                 }
#             },
#             "times": {
#                 "data_labeler_predict": 0.5704
#             }
#         },
#         "statistics": {
#             "vocab": "['q', '\u2019', 'x', 'H', '[', ... , '6', '\\n', 'E', 'p', 'd']",
#             "words": "['edited', '9', 'hours', ... , 'printing', 'automatically', 'rest']",
#             "word_count": {
#                 "ago": 205,
#                 "level": 203,
#                 "Reply": 195,
#                 "Share": 195,
#                 "Report": 195,
#                 "Save": 195,
#                 "gold": 195,
#                 "code": 175,
#                 "hours": 161,
#                 "points": 145,
#                 "3": 113,
#                 "1": 106,
#                 "2": 103,
#                 "4": 96,
#                 "point": 68,
#                 "6": 56,
#                 "5": 56,
#                 "data": 40,
#                 "tests": 39,
#                 "function": 34,
#                 "like": 34,
#                 "return": 33,
#                 "comments": 33,
#                 "need": 32,
#                 "time": 32,
#                 "write": 32,
#                 "abstraction": 31,
#                 "7": 30,
#                 "lines": 28,
#                 "null": 28,
#                 "use": 26,
#                 "8": 25,
#                 "hour": 23,
#                 "comment": 23,
#                 "way": 22,
#                 "test": 22,
#                 "name": 21,
#                 "complex": 20,
#                 "long": 20,
#                 "understand": 20,
#                 "string": 20,
#                 "think": 19,
#                 "example": 19,
#                 "read": 19,
#                 "minutes": 19,
#                 "method": 19,
#                 "functions": 19,
#                 "names": 18,
#                 "problem": 17,
#                 "writing": 17,
#                 "better": 17,
#                 "class": 17,
#                 "good": 17,
#                 "hard": 16,
#                 "thing": 16,
#                 "right": 16,
#                 "line": 16,
#                 "want": 15,
#                 "C": 15,
#                 "things": 14,
#                 "character": 14,
#                 "intermediate": 14,
#                 "limit": 14,
#                 "different": 13,
#                 "rule": 13,
#                 "wrong": 13,
#                 "lot": 13,
#                 "know": 13,
#                 "business": 12,
#                 "rules": 12,
#                 "change": 12,
#                 "find": 12,
#                 "context": 12,
#                 "simple": 12,
#                 "const": 12,
#                 "_foo": 12,
#                 "single": 11,
#                 "needs": 11,
#                 "duplication": 11,
#                 "makes": 11,
#                 "variable": 11,
#                 "classes": 11,
#                 "obvious": 11,
#                 "mean": 11,
#                 "solution": 11,
#                 "easier": 10,
#                 "number": 10,
#                 "actually": 10,
#                 "bad": 10,
#                 "set": 10,
#                 "multiple": 10,
#                 "said": 10,
#                 "optional": 10,
#                 "edited": 9,
#                 "9": 9,
#                 "case": 9,
#                 "people": 9,
#                 "place": 9,
#                 "helper": 9,
#                 "possible": 9,
#                 "b": 9,
#                 "replies": 9,
#                 "means": 9,
#                 "later": 9,
#                 "descriptive": 9,
#                 "look": 9,
#                 "Type": 9,
#                 "explain": 9,
#                 "readable": 9,
#                 "Simple": 9,
#                 "Query": 9,
#                 "ZorbaTHut": 9,
#                 "out_filename": 9,
#                 "similar": 8,
#                 "trying": 8,
#                 "great": 8,
#                 "common": 8,
#                 "complicated": 8,
#                 "come": 8,
#                 "important": 8,
#                 "easy": 8,
#                 "going": 8,
#                 "end": 8,
#                 "object": 8,
#                 "probably": 8,
#                 "space": 8,
#                 "work": 8,
#                 "Maybe": 8,
#                 "type": 8,
#                 "80": 8,
#                 "characters": 8,
#                 "ZapruderCondensed": 8,
#                 "Number": 8,
#                 "generic": 7,
#                 "usually": 7,
#                 "best": 7,
#                 "fix": 7,
#                 "save": 7,
#                 "cases": 7,
#                 "isolated": 7,
#                 "real": 7,
#                 "program": 7,
#                 "developer": 7,
#                 "break": 7,
#                 "written": 7,
#                 "instead": 7,
#                 "works": 7,
#                 "copy": 7,
#                 "requires": 7,
#                 "variables": 7,
#                 "general": 7,
#                 "codebase": 7,
#                 "choice": 7,
#                 "wrap": 7,
#                 "guideline": 7,
#                 "allow": 7,
#                 "public": 7,
#                 "Foo": 7,
#                 "more_intermediate": 7,
#                 "pieces": 6,
#                 "behavior": 6,
#                 "application": 6,
#                 "new": 6,
#                 "Removing": 6,
#                 "explaining": 6,
#                 "Yeah": 6,
#                 "caller": 6,
#                 "needed": 6,
#                 "abstractions": 6,
#                 "duplicated": 6,
#                 "complexity": 6,
#                 "reason": 6,
#                 "short": 6,
#                 "13": 6,
#                 "encourage": 6,
#                 "10": 6,
#                 "agree": 6,
#                 "types": 6,
#                 "Function": 6,
#                 "guidelines": 6,
#                 "incorrect": 6,
#                 "developers": 6,
#                 "n": 6,
#                 "0": 6,
#                 "dpash": 6,
#                 "combinatorylogic": 6,
#                 "value": 6,
#                 "looks": 6,
#                 "void": 6,
#                 "x": 6,
#                 "advice": 6,
#                 "tokens": 6,
#                 "bool": 6,
#                 "convert_zapruder_to_shazbot": 6,
#                 "Java": 6,
#                 "spaces": 6,
#                 "design": 6,
#                 "duplicate": 5,
#                 "following": 5,
#                 "shared": 5,
#                 "breaking": 5,
#                 "win": 5,
#                 "handling": 5,
#                 "far": 5,
#                 "unreadable": 5,
#                 "parameters": 5,
#                 "start": 5,
#                 "key": 5,
#                 "purpose": 5,
#                 "looking": 5,
#                 "saying": 5,
#                 "bug": 5,
#                 "sacrificing": 5,
#                 "libraries": 5,
#                 "day": 5,
#                 "weird": 5,
#                 "update": 5,
#                 "huge": 5,
#                 "pass": 5,
#                 "sort": 5,
#                 "sense": 5,
#                 "100": 5,
#                 "team": 5,
#                 "list": 5,
#                 "clean": 5,
#                 "times": 5,
#                 "remember": 5,
#                 "got": 5,
#                 "Element": 5,
#                 "useful": 5,
#                 "g": 5,
#                 "var": 5,
#                 "tell": 5,
#                 "open": 5,
#                 "writer": 5,
#                 "verbose": 5,
#                 "files": 5,
#                 "readability": 5,
#                 "involve": 5,
#                 "Sure": 5,
#                 "private": 5,
#                 "Table": 5,
#                 "Name": 5,
#                 "String": 5,
#                 "muntoo": 5,
#                 "converted": 5,
#                 "intermediate_data": 5,
#                 "language": 5,
#                 "Prefix": 5,
#                 "returns": 5,
#                 "user": 5,
#                 "print_error": 5,
#                 "try": 4,
#                 "DRY": 4,
#                 "special": 4,
#                 "handle": 4,
#                 "source": 4,
#                 "job": 4,
#                 "piece": 4,
#                 "situation": 4,
#                 "specific": 4,
#                 "software": 4,
#                 "IDEs": 4,
#                 "simply": 4,
#                 "difficult": 4,
#                 "longer": 4,
#                 "making": 4,
#                 "trivial": 4,
#                 "changes": 4,
#                 "system": 4,
#                 "little": 4,
#                 "possibly": 4,
#                 "stuff": 4,
#                 "refactor": 4,
#                 "file": 4,
#                 "help": 4,
#                 "shit": 4,
#                 "big": 4,
#                 "smart": 4,
#                 "stupid": 4,
#                 "testing": 4,
#                 "24": 4,
#                 "problems": 4,
#                 "14": 4,
#                 "seen": 4,
#                 "verify": 4,
#                 "yeah": 4,
#                 "meaning": 4,
#                 "small": 4,
#                 "required": 4,
#                 "dependencies": 4,
#                 "dozen": 4,
#                 "able": 4,
#                 "robotreader": 4,
#                 "necessarily": 4,
#                 "thought": 4,
#                 "Write": 4,
#                 "telling": 4,
#                 "comes": 4,
#                 "OneWingedShark": 4,
#                 "values": 4,
#                 "parameter": 4,
#                 "23": 4,
#                 "naming": 4,
#                 "Code": 4,
#                 "maybe": 4,
#                 "IMO": 4,
#                 "person": 4,
#                 "helpful": 4,
#                 "form": 4,
#                 "working": 4,
#                 "based": 4,
#                 "methods": 4,
#                 "style": 4,
#                 "Comments": 4,
#                 "WriteLine": 4,
#                 "HelperClass": 4,
#                 "r": 4,
#                 "kind": 4,
#                 "thinking": 4,
#                 "errors": 4,
#                 "story": 4,
#                 "Knuth": 4,
#                 "54": 4,
#                 "paper": 4,
#                 "disagree": 4,
#                 "sure": 4,
#                 "Get_Name": 4,
#                 "solve": 4,
#                 "OOP": 4,
#                 "140": 4,
#                 "120": 4,
#                 "standard": 4,
#                 "length": 4,
#                 "shorter": 4,
#                 "NonEmptySet": 4,
#                 "input": 4,
#                 "auto": 4,
#                 "word": 4,
#                 "tabs": 4,
#                 "hand": 4,
#                 "nulls": 4,
#                 "Null": 4,
#                 "initialize": 4,
#                 "patterns": 4,
#                 "holder": 4,
#                 "totally": 3,
#                 "lead": 3,
#                 "fit": 3,
#                 "run": 3,
#                 "phpdevster": 3,
#                 "resist": 3,
#                 "costs": 3,
#                 "dealing": 3,
#                 "abstracted": 3,
#                 "bits": 3,
#                 "reusable": 3,
#                 "reused": 3,
#                 "lost": 3,
#                 "NotSoButFarOtherwise": 3,
#                 "wrote": 3,
#                 "concept": 3,
#                 "current": 3,
#                 "bugs": 3,
#                 "quickly": 3,
#                 "12": 3,
#                 "months": 3,
#                 "game": 3,
#                 "reuse": 3,
#                 "realize": 3,
#                 "abstract": 3,
#                 "second": 3,
#                 "crap": 3,
#                 "effects": 3,
#                 "reply": 3,
#                 "framework": 3,
#                 "mess": 3,
#                 "feel": 3,
#                 "presence": 3,
#                 "statement": 3,
#                 "fail": 3,
#                 "e": 3,
#                 "nice": 3,
#                 "elperroborrachotoo": 3,
#                 "solving": 3,
#                 "green": 3,
#                 "Yes": 3,
#                 "devs": 3,
#                 "pasting": 3,
#                 "guess": 3,
#                 "Like": 3,
#                 "result": 3,
#                 "keeping": 3,
#                 "setup": 3,
#                 "frequently": 3,
#                 "KaltherX": 3,
#                 "changing": 3,
#                 "shaege": 3,
#                 "hell": 3,
#                 "share": 3,
#                 "logic": 3,
#                 "campbellm": 3,
#                 "non": 3,
#                 "Count": 3,
#                 "matter": 3,
#                 "related": 3,
#                 "Ada": 3,
#                 "Left": 3,
#                 "Right": 3,
#                 "Input": 3,
#                 "actual": 3,
#                 "Comment": 3,
#                 "sparingly": 3,
#                 "state": 3,
#                 "impossible": 3,
#                 "Better": 3,
#                 "etc": 3,
#                 "achieve": 3,
#                 "fits": 3,
#                 "screen": 3,
#                 "obviously": 3,
#                 "clear": 3,
#                 "document": 3,
#                 "expect": 3,
#                 "information": 3,
#                 "process": 3,
#                 "forces": 3,
#                 "turn": 3,
#                 "debugging": 3,
#                 "functionality": 3,
#                 "course": 3,
#                 "acquireFileWriterBySomeMeans": 3,
#                 "instance": 3,
#                 "hope": 3,
#                 "love": 3,
#                 "Types": 3,
#                 "c": 3,
#                 "principle": 3,
#                 "errno": 3,
#                 "assume": 3,
#                 "sake": 3,
#                 "Habadasher": 3,
#                 "bigger": 3,
#                 "explains": 3,
#                 "spread": 3,
#                 "compiler": 3,
#                 "free": 3,
#                 "chunk": 3,
#                 "early": 3,
#                 "emorrp1": 3,
#                 "play": 3,
#                 "30": 3,
#                 "deep": 3,
#                 "takes": 3,
#                 "functional": 3,
#                 "wish": 3,
#                 "Package": 3,
#                 "DB": 3,
#                 "returning": 3,
#                 "DB_Input_String": 3,
#                 "DB_Output_String": 3,
#                 "Do_SQL": 3,
#                 "Sanitize": 3,
#                 "Parse": 3,
#                 "dirty": 3,
#                 "potentially": 3,
#                 "reference": 3,
#                 "weak": 3,
#                 "argument": 3,
#                 "Split": 3,
#                 "holders": 3,
#                 "manipulators": 3,
#                 "essentially": 3,
#                 "monitor": 3,
#                 "16": 3,
#                 "easily": 3,
#                 "Double_A_92": 3,
#                 "print": 3,
#                 "members": 3,
#                 "IDE": 3,
#                 "avoid": 3,
#                 "exactly": 3,
#                 "alaskanarcher": 3,
#                 "formatting": 3,
#                 "issue": 3,
#                 "confusing": 3,
#                 "talking": 3,
#                 "require": 3,
#                 "practice": 3,
#                 "partitionPkgs": 3,
#                 "toEither": 3,
#                 "languages": 3,
#                 "literally": 3,
#                 "zapruder": 3,
#                 "in_filename": 3,
#                 "another_out_filename": 3,
#                 "preshazbot": 3,
#                 "zapruder_to_shazbot": 3,
#                 "reasonable": 3,
#                 "dozens": 3,
#                 "Classes": 3,
#                 "VS": 3,
#                 "default": 3,
#                 "namespace": 3,
#                 "indents": 3,
#                 "indent": 3,
#                 "true": 3,
#                 "properties": 3,
#                 "jcelerier": 3,
#                 "breaks": 3,
#                 "abomination": 3,
#                 "eyal0": 3,
#                 "phone": 3,
#                 "nullable": 3,
#                 "world": 3,
#                 "atomic": 3,
#                 "display": 3,
#                 "access": 3,
#                 "cows": 3,
#                 "exit": 3,
#                 "caution": 2,
#                 "rigidly": 2,
#                 "represent": 2,
#                 "inadvertently": 2,
#                 "coupled": 2,
#                 "modify": 2,
#                 "truth": 2,
#                 "repeats": 2,
#                 "exact": 2,
#                 "handles": 2,
#                 "luckygerbils": 2,
#                 "article": 2,
#                 "33": 2,
#                 "passed": 2,
#                 "reduces": 2,
#                 "completely": 2,
#                 "old": 2,
#                 "believe": 2,
#                 "paradox": 2,
#                 "fragile": 2,
#                 "development": 2,
#                 "underlying": 2,
#                 "opportunity": 2,
#                 "reusing": 2,
#                 "17": 2,
#                 "de": 2,
#                 "happens": 2,
#                 "subtle": 2,
#                 "especially": 2,
#                 "alternative": 2,
#                 "IME": 2,
#                 "decent": 2,
#                 "limits": 2,
#                 "future": 2,
#                 "found": 2,
#                 "paths": 2,
#                 "contributing": 2,
#                 "fundamental": 2,
#                 "parts": 2,
#                 "maintainability": 2,
#                 "base": 2,
#                 "products": 2,
#                 "situations": 2,
#                 "yes": 2,
#                 "53": 2,
#                 "spend": 2,
#                 "Abstractions": 2,
#                 "declaration": 2,
#                 "size": 2,
#                 "NotMyRealNameObv": 2,
#                 "decide": 2,
#                 "doMagic": 2,
#                 "personal": 2,
#                 "Tests": 2,
#                 "transparent": 2,
#                 "theory": 2,
#                 "mutation": 2,
#                 "replacing": 2,
#                 "false": 2,
#                 "terms": 2,
#                 "tayo42": 2,
#                 "irbilldozer": 2,
#                 "forget": 2,
#                 "pretty": 2,
#                 "check": 2,
#                 "rate": 2,
#                 "ready": 2,
#                 "ship": 2,
#                 "turned": 2,
#                 "says": 2,
#                 "runs": 2,
#                 "NET": 2,
#                 "idea": 2,
#                 "stop": 2,
#                 "happening": 2,
#                 "helps": 2,
#                 "TheGRS": 2,
#                 "took": 2,
#                 "ignore": 2,
#                 "mark": 2,
#                 "Totally": 2,
#                 "tons": 2,
#                 "guy": 2,
#                 "engineers": 2,
#                 "rendered": 2,
#                 "implement": 2,
#                 "depends": 2,
#                 "separation": 2,
#                 "Ideally": 2,
#                 "high": 2,
#                 "human": 2,
#                 "treat": 2,
#                 "ForeverAlot": 2,
#                 "rely": 2,
#                 "blocks": 2,
#                 "hooks": 2,
#                 "individual": 2,
#                 "sharing": 2,
#                 "factored": 2,
#                 "liner": 2,
#                 "crunk": 2,
#                 "wanted": 2,
#                 "broke": 2,
#                 "structure": 2,
#                 "unit": 2,
#                 "reduce": 2,
#                 "model": 2,
#                 "inline": 2,
#                 "thumb": 2,
#                 "places": 2,
#                 "changed": 2,
#                 "19": 2,
#                 "oh": 2,
#                 "eventually": 2,
#                 "feels": 2,
#                 "lets": 2,
#                 "uses": 2,
#                 "catch": 2,
#                 "experience": 2,
#                 "pre": 2,
#                 "bit": 2,
#                 "question": 2,
#                 "twice": 2,
#                 "refactoring": 2,
#                 "flexible": 2,
#                 "callers": 2,
#                 "Honestly": 2,
#                 "strings": 2,
#                 "worst": 2,
#                 "pattern": 2,
#                 "allows": 2,
#                 "wide": 2,
#                 "range": 2,
#                 "Index": 2,
#                 "Array_Vector": 2,
#                 "Procedure": 2,
#                 "Boolean": 2,
#                 "reverse": 2,
#                 "systems": 2,
#                 "Avoid": 2,
#                 "increased": 2,
#                 "technical": 2,
#                 "debit": 2,
#                 "finding": 2,
#                 "frameworks": 2,
#                 "life": 2,
#                 "domain": 2,
#                 "aware": 2,
#                 "today": 2,
#                 "strange": 2,
#                 "20": 2,
#                 "harder": 2,
#                 "block": 2,
#                 "meaningful": 2,
#                 "employees": 2,
#                 "employee": 2,
#                 "include": 2,
#                 "inputs": 2,
#                 "clever": 2,
#                 "thinks": 2,
#                 "logs": 2,
#                 "background": 2,
#                 "teaching": 2,
#                 "effective": 2,
#                 "students": 2,
#                 "rare": 2,
#                 "Open": 2,
#                 "filename": 2,
#                 "project": 2,
#                 "looked": 2,
#                 "Console": 2,
#                 "instansiate": 2,
#                 "HelperCLass": 2,
#                 "create": 2,
#                 "helperClass": 2,
#                 "Created": 2,
#                 "TomLikesGuitar": 2,
#                 "examples": 2,
#                 "text": 2,
#                 "solved": 2,
#                 "BLCKSZ": 2,
#                 "bizarre": 2,
#                 "simplify": 2,
#                 "absolutely": 2,
#                 "add": 2,
#                 "Method": 2,
#                 "usage": 2,
#                 "sounds": 2,
#                 "utter": 2,
#                 "lunacy": 2,
#                 "essay": 2,
#                 "referring": 2,
#                 "papers": 2,
#                 "citing": 2,
#                 "specification": 2,
#                 "paragraphs": 2,
#                 "implementing": 2,
#                 "explicitly": 2,
#                 "Donald": 2,
#                 "lunatic": 2,
#                 "hipstor": 2,
#                 "webapps": 2,
#                 "inside": 2,
#                 "TeX": 2,
#                 "quality": 2,
#                 "willing": 2,
#                 "cheques": 2,
#                 "discover": 2,
#                 "assumptions": 2,
#                 "plus": 2,
#                 "idolisation": 2,
#                 "man": 2,
#                 "programming": 2,
#                 "personally": 2,
#                 "days": 2,
#                 "MagicMurderBagYT": 2,
#                 "correct": 2,
#                 "head": 2,
#                 "nearly": 2,
#                 "simplicity": 2,
#                 "get_salled": 2,
#                 "revisions": 2,
#                 "understanding": 2,
#                 "quick": 2,
#                 "worse": 2,
#                 "version": 2,
#                 "python": 2,
#                 "oriented": 2,
#                 "26": 2,
#                 "self": 2,
#                 "imagine": 2,
#                 "phySi0": 2,
#                 "away": 2,
#                 "invalid": 2,
#                 "User": 2,
#                 "touch": 2,
#                 "simpler": 2,
#                 "ability": 2,
#                 "learned": 2,
#                 "leaving": 2,
#                 "MarkIsntWorkingNow": 2,
#                 "34": 2,
#                 "15": 2,
#                 "typing": 2,
#                 "figure": 2,
#                 "prefered": 2,
#                 "geft": 2,
#                 "0987654231": 2,
#                 "provide": 2,
#                 "gone": 2,
#                 "redditthinks": 2,
#                 "Use": 2,
#                 "continue": 2,
#                 "Short": 2,
#                 "expression": 2,
#                 "half": 2,
#                 "Given": 2,
#                 "kill": 2,
#                 "cheap": 2,
#                 "YM_Industries": 2,
#                 "split": 2,
#                 "200": 2,
#                 "ugly": 2,
#                 "scroll": 2,
#                 "horizontally": 2,
#                 "Additionally": 2,
#                 "impact": 2,
#                 "300": 2,
#                 "pen": 2,
#                 "soft": 2,
#                 "original": 2,
#                 "Long": 2,
#                 "i_hate_readability_a_whole_lot": 2,
#                 "certain": 2,
#                 "w": 2,
#                 "designs": 2,
#                 "reasonably": 2,
#                 "input_zapruder_data": 2,
#                 "output_shazbot_filename": 2,
#                 "TransformedBy": 2,
#                 "weapWorld": 2,
#                 "charWorld": 2,
#                 "losing": 2,
#                 "provides": 2,
#                 "pulled": 2,
#                 "notify": 2,
#                 "IO": 2,
#                 "ss": 2,
#                 "liftMaybeM": 2,
#                 "Member": 2,
#                 "NonEmpty": 2,
#                 "Prebuilt": 2,
#                 "Buildable": 2,
#                 "f": 2,
#                 "toList": 2,
#                 "let": 2,
#                 "internal": 2,
#                 "issues": 2,
#                 "output": 2,
#                 "post": 2,
#                 "generateTempFilename": 2,
#                 "PreShazbot": 2,
#                 "temporary_data": 2,
#                 "module": 2,
#                 "assuming": 2,
#                 "scope": 2,
#                 "scopes": 2,
#                 "modern": 2,
#                 "IntelliJ": 2,
#                 "editors": 2,
#                 "Hmm": 2,
#                 "checked": 2,
#                 "curious_s": 2,
#                 "getters": 2,
#                 "setters": 2,
#                 "waaay": 2,
#                 "vertical": 2,
#                 "Otis_Inf": 2,
#                 "property": 2,
#                 "ok": 2,
#                 "NS": 2,
#                 "sweet": 2,
#                 "foo": 2,
#                 "do_bar": 2,
#                 "do_baz": 2,
#                 "nested": 2,
#                 "Necromunger": 2,
#                 "conditions": 2,
#                 "forgot": 2,
#                 "failure": 2,
#                 "width": 2,
#                 "bunch": 2,
#                 "valid": 2,
#                 "relevant": 2,
#                 "NULL": 2,
#                 "exception": 2,
#                 "username": 2,
#                 "Edit": 2,
#                 "warn": 2,
#                 "accepting": 2,
#                 "Optional": 2,
#                 "collection": 2,
#                 "Calcd_Uncertainty": 2,
#                 "generalisation": 2,
#                 "indication": 2,
#                 "GoF": 2,
#                 "vocabulary": 2,
#                 "describe": 2,
#                 "entities": 2,
#                 "challenge": 2,
#                 "goes": 2,
#                 "uncle": 2,
#                 "11": 2,
#                 "Thank": 2,
#                 "yojimbo_beta": 2,
#                 "vs": 2,
#                 "admin": 2,
#                 "javascript": 2,
#                 "modal": 2,
#                 "contexts": 2,
#                 "nesting": 2,
#                 "pato_p": 2,
#                 "error": 2,
#                 "maintenance": 2,
#                 "things_are_broken": 2,
#                 "input_is_invalid": 2,
#                 "easy_common_solution": 2,
#                 "simple_answer": 2,
#                 "do_some_prep": 2,
#                 "prep_failed": 2,
#                 "less_easy_solution": 2,
#                 "less_simple_answer": 2,
#                 "weird_special_case": 2,
#                 "perflog_event": 2,
#                 "FULL_ANSWER_REQUIRED": 2,
#                 "lots_more_prep": 2,
#                 "invalid_state": 2,
#                 "degenerate_result": 2,
#                 "potential": 1,
#                 "unrelated": 1,
#                 "creep": 1,
#                 "requirements": 1,
#                 "110": 1,
#                 "Duplication": 1,
#                 "cheaper": 1,
#                 "interesting": 1,
#                 "driven": 1,
#                 "sunk": 1,
#                 "fastest": 1,
#                 "forward": 1,
#                 "introduce": 1,
#                 "inlining": 1,
#                 "determine": 1,
#                 "subset": 1,
#                 "inlined": 1,
#                 "executes": 1,
#                 "Delete": 1,
#                 "particular": 1,
#                 "removes": 1,
#                 "conditionals": 1,
#                 "rewind": 1,
#                 "decisions": 1,
#                 "ostensibly": 1,
#                 "invoked": 1,
#                 "running": 1,
#                 "fairly": 1,
#                 "unique": 1,
#                 "remove": 1,
#                 "anew": 1,
#                 "isolating": 1,
#                 "extracting": 1,
#                 "led": 1,
#                 "fundamentally": 1,
#                 "challenging": 1,
#                 "abstracting": 1,
#                 "divergent": 1,
#                 "skill": 1,
#                 "salbris": 1,
#                 "okay": 1,
#                 "build": 1,
#                 "aseigo": 1,
#                 "absyractions": 1,
#                 "given": 1,
#                 "bounty": 1,
#                 "locality": 1,
#                 "defects": 1,
#                 "increasing": 1,
#                 "odds": 1,
#                 "tracking": 1,
#                 "reliability": 1,
#                 "achievable": 1,
#                 "alike": 1,
#                 "predictable": 1,
#                 "results": 1,
#                 "collects": 1,
#                 "concepts": 1,
#                 "consistebt": 1,
#                 "interfaces": 1,
#                 "aka": 1,
#                 "familiar": 1,
#                 "repetition": 1,
#                 "changers": 1,
#                 "worked": 1,
#                 "handled": 1,
#                 "components": 1,
#                 "compatibility": 1,
#                 "desperately": 1,
#                 "effort": 1,
#                 "competing": 1,
#                 "crumbled": 1,
#                 "term": 1,
#                 "expertise": 1,
#                 "primarily": 1,
#                 "Knowing": 1,
#                 "appreciable": 1,
#                 "immediate": 1,
#                 "pays": 1,
#                 "leveragable": 1,
#                 "intrinsically": 1,
#                 "senikaya": 1,
#                 "moment": 1,
#                 "decided": 1,
#                 "usual": 1,
#                 "genius": 1,
#                 "retarded": 1,
#                 "fast": 1,
#                 "slower": 1,
#                 "fully": 1,
#                 "constant": 1,
#                 "impl": 1,
#                 "ones": 1,
#                 "trust": 1,
#                 "distinctions": 1,
#                 "usualshoes": 1,
#                 "cram": 1,
#                 "ideal": 1,
#                 "nicely": 1,
#                 "decoupled": 1,
#                 "104": 1,
#                 "applies": 1,
#                 "obsessed": 1,
#                 "minimizing": 1,
#                 "littered": 1,
#                 "behaviour": 1,
#                 "setupTest": 1,
#                 "teardownTest": 1,
#                 "opinion": 1,
#                 "leaning": 1,
#                 "indepentent": 1,
#                 "74": 1,
#                 "forsakenharmony": 1,
#                 "prove": 1,
#                 "absence": 1,
#                 "parabol443": 1,
#                 "flip": 1,
#                 "correctly": 1,
#                 "coverage": 1,
#                 "Unit": 1,
#                 "arise": 1,
#                 "Bad": 1,
#                 "unclear": 1,
#                 "security": 1,
#                 "Uhhh": 1,
#                 "marks": 1,
#                 "cares": 1,
#                 "dude": 1,
#                 "Mhhh": 1,
#                 "Checkmarks": 1,
#                 "Green": 1,
#                 "environment": 1,
#                 "9034725985": 1,
#                 "Git": 1,
#                 "blame": 1,
#                 "year": 1,
#                 "saw": 1,
#                 "bamboo": 1,
#                 "ASP": 1,
#                 "MVC": 1,
#                 "Things": 1,
#                 "continuously": 1,
#                 "fake": 1,
#                 "organizational": 1,
#                 "uncommon": 1,
#                 "consistently": 1,
#                 "commenting": 1,
#                 "entire": 1,
#                 "kept": 1,
#                 "started": 1,
#                 "skip": 1,
#                 "alerted": 1,
#                 "band": 1,
#                 "aid": 1,
#                 "commented": 1,
#                 "HardLiquorSoftDrinks": 1,
#                 "52": 1,
#                 "cracked": 1,
#                 "pushed": 1,
#                 "price": 1,
#                 "produced": 1,
#                 "units": 1,
#                 "decimal": 1,
#                 "195": 1,
#                 "0000": 1,
#                 "QA": 1,
#                 "Drainedsoul": 1,
#                 "apply": 1,
#                 "position": 1,
#                 "entered": 1,
#                 "step": 1,
#                 "infinite": 1,
#                 "regress": 1,
#                 "Luolong": 1,
#                 "heavily": 1,
#                 "exhibit": 1,
#                 "concerns": 1,
#                 "compose": 1,
#                 "scenario": 1,
#                 "ordered": 1,
#                 "instructions": 1,
#                 "tester": 1,
#                 "respect": 1,
#                 "production": 1,
#                 "fine": 1,
#                 "inherently": 1,
#                 "purely": 1,
#                 "preparing": 1,
#                 "effectively": 1,
#                 "Calsem": 1,
#                 "testinitialize": 1,
#                 "cleanup": 1,
#                 "opaque": 1,
#                 "colleagues": 1,
#                 "typical": 1,
#                 "tear": 1,
#                 "JUnit": 1,
#                 "ilk": 1,
#                 "meaningfully": 1,
#                 "initialization": 1,
#                 "pure": 1,
#                 "field": 1,
#                 "recently": 1,
#                 "experienced": 1,
#                 "hundreds": 1,
#                 "generated": 1,
#                 "Pretty": 1,
#                 "programme": 1,
#                 "loathing": 1,
#                 "crucial": 1,
#                 "demonstrate": 1,
#                 "SUT": 1,
#                 "singleton": 1,
#                 "derived": 1,
#                 "care": 1,
#                 "ffs": 1,
#                 "HIDE": 1,
#                 "ing": 1,
#                 "giving": 1,
#                 "strong": 1,
#                 "hints": 1,
#                 "fucking": 1,
#                 "hint": 1,
#                 "Stop_Sign": 1,
#                 "biggest": 1,
#                 "complaints": 1,
#                 "page": 1,
#                 "mentalfingertrap": 1,
#                 "Inline": 1,
#                 "teardown": 1,
#                 "temptation": 1,
#                 "Copy": 1,
#                 "paste": 1,
#                 "independent": 1,
#                 "worth": 1,
#                 "21": 1,
#                 "repeated": 1,
#                 "extract": 1,
#                 "mhink": 1,
#                 "gotta": 1,
#                 "stress": 1,
#                 "caught": 1,
#                 "trap": 1,
#                 "fall": 1,
#                 "tough": 1,
#                 "stopping": 1,
#                 "oneself": 1,
#                 "heh": 1,
#                 "csjerk": 1,
#                 "separates": 1,
#                 "expressive": 1,
#                 "fashion": 1,
#                 "duping": 1,
#                 "spot": 1,
#                 "worry": 1,
#                 "ugh": 1,
#                 "tedious": 1,
#                 "settled": 1,
#                 "trigger": 1,
#                 "philosophy": 1,
#                 "demonstrably": 1,
#                 "pydry": 1,
#                 "anybody": 1,
#                 "wasted": 1,
#                 "damn": 1,
#                 "near": 1,
#                 "close": 1,
#                 "emptively": 1,
#                 "designing": 1,
#                 "pay": 1,
#                 "fundamentalist": 1,
#                 "reddit_prog": 1,
#                 "ask": 1,
#                 "3rd": 1,
#                 "THINK": 1,
#                 "burned": 1,
#                 "consolidated": 1,
#                 "oooh": 1,
#                 "snap": 1,
#                 "thingy": 1,
#                 "Eventually": 1,
#                 "inflexible": 1,
#                 "consuming": 1,
#                 "magic": 1,
#                 "burn": 1,
#                 "Magic": 1,
#                 "numbers": 1,
#                 "absolute": 1,
#                 "NAN001": 1,
#                 "moderately": 1,
#                 "identical": 1,
#                 "edits": 1,
#                 "Let": 1,
#                 "express": 1,
#                 "caveman": 1,
#                 "Semantics": 1,
#                 "implementation": 1,
#                 "Correlation": 1,
#                 "intent": 1,
#                 "TheAwdacityOfSoap": 1,
#                 "sentiment": 1,
#                 "entirety": 1,
#                 "trick": 1,
#                 "deduplicating": 1,
#                 "mardiros": 1,
#                 "happy": 1,
#                 "upvote": 1,
#                 "36": 1,
#                 "fair": 1,
#                 "severely": 1,
#                 "mitigated": 1,
#                 "generics": 1,
#                 "subprograms": 1,
#                 "packages": 1,
#                 "addition": 1,
#                 "decomposition": 1,
#                 "Generic": 1,
#                 "Array": 1,
#                 "Exchange": 1,
#                 "B": 1,
#                 "Generic_Sort": 1,
#                 "instantiation": 1,
#                 "associate": 1,
#                 "direction": 1,
#                 "scales": 1,
#                 "sub": 1,
#                 "True": 1,
#                 "28": 1,
#                 "wthidden": 1,
#                 "83": 1,
#                 "simplified": 1,
#                 "Functions": 1,
#                 "Names": 1,
#                 "plan": 1,
#                 "spending": 1,
#                 "hidden": 1,
#                 "review": 1,
#                 "thoughts": 1,
#                 "consistent": 1,
#                 "Adapting": 1,
#                 "introduces": 1,
#                 "unneeded": 1,
#                 "lifecycle": 1,
#                 "saving": 1,
#                 "cycle": 1,
#                 "address": 1,
#                 "maintainer": 1,
#                 "Shiny": 1,
#                 "rusted": 1,
#                 "leaky": 1,
#                 "tomorrow": 1,
#                 "LesSablesMouvants": 1,
#                 "college": 1,
#                 "necessary": 1,
#                 "docs": 1,
#                 "iampx": 1,
#                 "codeblocks": 1,
#                 "behaivour": 1,
#                 "overkill": 1,
#                 "cynicaloctopus": 1,
#                 "58": 1,
#                 "extracted": 1,
#                 "Captain___Obvious": 1,
#                 "smarter": 1,
#                 "Computer": 1,
#                 "Science": 1,
#                 "cache": 1,
#                 "invalidation": 1,
#                 "Phil": 1,
#                 "Karlton": 1,
#                 "TimeRemove": 1,
#                 "golden": 1,
#                 "Explaining": 1,
#                 "million": 1,
#                 "contained": 1,
#                 "forever": 1,
#                 "loop": 1,
#                 "Vs": 1,
#                 "Inverted": 1,
#                 "alphabetical": 1,
#                 "view": 1,
#                 "insight": 1,
#                 "signs": 1,
#                 "fresh": 1,
#                 "university": 1,
#                 "describing": 1,
#                 "getter": 1,
#                 "outputs": 1,
#                 "exceptions": 1,
#                 "gotchas": 1,
#                 "Documentation": 1,
#                 "javadoc": 1,
#                 "phpdoc": 1,
#                 "jsdoc": 1,
#                 "warning": 1,
#                 "belong": 1,
#                 "commit": 1,
#                 "Particularly": 1,
#                 "folkrav": 1,
#                 "didactics": 1,
#                 "rationale": 1,
#                 "intentions": 1,
#                 "assignments": 1,
#                 "teacher": 1,
#                 "partially": 1,
#                 "prevents": 1,
#                 "knowing": 1,
#                 "justify": 1,
#                 "tool": 1,
#                 "desirable": 1,
#                 "vine": 1,
#                 "el": 1,
#                 "professors": 1,
#                 "school": 1,
#                 "rubber": 1,
#                 "ducky": 1,
#                 "student": 1,
#                 "leading": 1,
#                 "ah": 1,
#                 "hah": 1,
#                 "moments": 1,
#                 "flaws": 1,
#                 "slapping": 1,
#                 "starting": 1,
#                 "uni": 1,
#                 "Nowadays": 1,
#                 "majority": 1,
#                 "GhostDoc": 1,
#                 "generates": 1,
#                 "appease": 1,
#                 "cop": 1,
#                 "determined": 1,
#                 "debug": 1,
#                 "P": 1,
#                 "tcpukl": 1,
#                 "22": 1,
#                 "dont_judge_me_monkey": 1,
#                 "File": 1,
#                 "jfc": 1,
#                 "Jeffy29": 1,
#                 "x3": 1,
#                 "name_variable": 1,
#                 "CollegeCode": 1,
#                 "jrop": 1,
#                 "inherited": 1,
#                 "virtually": 1,
#                 "operation": 1,
#                 "store": 1,
#                 "buried": 1,
#                 "noise": 1,
#                 "logging": 1,
#                 "refactored": 1,
#                 "NLog": 1,
#                 "understood": 1,
#                 "ported": 1,
#                 "scripts": 1,
#                 "posted": 1,
#                 "snippets": 1,
#                 "ProgrammingHorror": 1,
#                 "fragglerock": 1,
#                 "broad": 1,
#                 "super": 1,
#                 "gist": 1,
#                 "opening": 1,
#                 "looping": 1,
#                 "processor": 1,
#                 "immensely": 1,
#                 "implied": 1,
#                 "glyph": 1,
#                 "advance": 1,
#                 "end_bytes": 1,
#                 "UTF8": 1,
#                 "NextUnsafe": 1,
#                 "glyphVal": 1,
#                 "doublehyphen": 1,
#                 "57": 1,
#                 "PostgreSQL": 1,
#                 "helped": 1,
#                 "fd": 1,
#                 "page_buffer": 1,
#                 "slotno": 1,
#                 "pgstat_report_wait_end": 1,
#                 "disk": 1,
#                 "ENOSPC": 1,
#                 "44": 1,
#                 "difference": 1,
#                 "stylistic": 1,
#                 "kinda": 1,
#                 "brief": 1,
#                 "inmatarian": 1,
#                 "Reduce": 1,
#                 "riskable": 1,
#                 "savers": 1,
#                 "standardization": 1,
#                 "implementations": 1,
#                 "sorting": 1,
#                 "wished": 1,
#                 "maintained": 1,
#                 "alongside": 1,
#                 "overly": 1,
#                 "orthogonal": 1,
#                 "necessitates": 1,
#                 "programmers": 1,
#                 "minimal": 1,
#                 "cause": 1,
#                 "crash": 1,
#                 "app": 1,
#                 "significantly": 1,
#                 "distracting": 1,
#                 "CRUD": 1,
#                 "mathematics": 1,
#                 "steps": 1,
#                 "implicit": 1,
#                 "constraints": 1,
#                 "infer": 1,
#                 "thinly": 1,
#                 "contribution": 1,
#                 "Lot": 1,
#                 "infallible": 1,
#                 "outnumber": 1,
#                 "lots": 1,
#                 "equates": 1,
#                 "sammymammy2": 1,
#                 "literal": 1,
#                 "aedrin": 1,
#                 "unusual": 1,
#                 "belongs": 1,
#                 "KlausKoe": 1,
#                 "ran": 1,
#                 "bburc": 1,
#                 "dev": 1,
#                 "accident": 1,
#                 "Goto80": 1,
#                 "Update": 1,
#                 "conventionally": 1,
#                 "separated": 1,
#                 "blank": 1,
#                 "reword": 1,
#                 "o11c": 1,
#                 "Framework": 1,
#                 "int2d": 1,
#                 "64": 1,
#                 "regularly": 1,
#                 "junior": 1,
#                 "senior": 1,
#                 "needlessly": 1,
#                 "matters": 1,
#                 "eyes": 1,
#                 "beholder": 1,
#                 "hide": 1,
#                 "dependent": 1,
#                 "leaked": 1,
#                 "Haskell": 1,
#                 "avoiding": 1,
#                 "awareness": 1,
#                 "encouragement": 1,
#                 "coming": 1,
#                 "recognition": 1,
#                 "Shookfr": 1,
#                 "Simpler": 1,
#                 "Consider": 1,
#                 "created": 1,
#                 "assured": 1,
#                 "Administrator": 1,
#                 "Company": 1,
#                 "col": 1,
#                 "Private": 1,
#                 "record": 1,
#                 "stub": 1,
#                 "End": 1,
#                 "sanitizing": 1,
#                 "connecting": 1,
#                 "resultant": 1,
#                 "presented": 1,
#                 "users": 1,
#                 "package": 1,
#                 "publicly": 1,
#                 "DoTheElectricEel": 1,
#                 "sign": 1,
#                 "compliment": 1,
#                 "gotten": 1,
#                 "redesigning": 1,
#                 "rewriting": 1,
#                 "portions": 1,
#                 "gigantic": 1,
#                 "suddenly": 1,
#                 "came": 1,
#                 "woodwork": 1,
#                 "Frank": 1,
#                 "franzwong": 1,
#                 "improve": 1,
#                 "control": 1,
#                 "cjh79": 1,
#                 "Somebody": 1,
#                 "wise": 1,
#                 "edge": 1,
#                 "fun": 1,
#                 "AegisToast": 1,
#                 "heard": 1,
#                 "professor": 1,
#                 "engineered": 1,
#                 "Kinglink": 1,
#                 "mad": 1,
#                 "ex": 1,
#                 "coworker": 1,
#                 "sadly": 1,
#                 "constantly": 1,
#                 "shutting": 1,
#                 "switching": 1,
#                 "modes": 1,
#                 "surprised": 1,
#                 "hit": 1,
#                 "tech": 1,
#                 "asked": 1,
#                 "some_function": 1,
#                 "sick": 1,
#                 "MrRogers4Life2": 1,
#                 "ya": 1,
#                 "Experienced": 1,
#                 "HATE": 1,
#                 "Klathmon": 1,
#                 "joke": 1,
#                 "ElBroet": 1,
#                 "weakly": 1,
#                 "typed": 1,
#                 "tryin": 1,
#                 "atrich": 1,
#                 "compiles": 1,
#                 "BobSacamano47": 1,
#                 "27": 1,
#                 "stood": 1,
#                 "explanation": 1,
#                 "IceSentry": 1,
#                 "hold": 1,
#                 "manipulates": 1,
#                 "Dog": 1,
#                 "supposed": 1,
#                 "ball": 1,
#                 "manipulator": 1,
#                 "getDog": 1,
#                 "getBall": 1,
#                 "separating": 1,
#                 "records": 1,
#                 "sushibowl": 1,
#                 "grouped": 1,
#                 "acts": 1,
#                 "Splitting": 1,
#                 "contrary": 1,
#                 "splitting": 1,
#                 "benefits": 1,
#                 "structures": 1,
#                 "plain": 1,
#                 "anemic": 1,
#                 "anti": 1,
#                 "18": 1,
#                 "hey": 1,
#                 "combine": 1,
#                 "simplest": 1,
#                 "spills": 1,
#                 "abolishing": 1,
#                 "answer": 1,
#                 "added": 1,
#                 "coding": 1,
#                 "standards": 1,
#                 "documents": 1,
#                 "Getting": 1,
#                 "rid": 1,
#                 "improvement": 1,
#                 "Breaking": 1,
#                 "lower": 1,
#                 "stay": 1,
#                 "chose": 1,
#                 "1080p": 1,
#                 "company": 1,
#                 "zoom": 1,
#                 "comfortable": 1,
#                 "font": 1,
#                 "smaller": 1,
#                 "plenty": 1,
#                 "room": 1,
#                 "leftover": 1,
#                 "minimap": 1,
#                 "mention": 1,
#                 "comprised": 1,
#                 "perfect": 1,
#                 "happily": 1,
#                 "liners": 1,
#                 "400": 1,
#                 "PHP": 1,
#                 "scene": 1,
#                 "formatter": 1,
#                 "committing": 1,
#                 "git": 1,
#                 "Unfortunately": 1,
#                 "formats": 1,
#                 "modified": 1,
#                 "leads": 1,
#                 "jagged": 1,
#                 "visually": 1,
#                 "uglier": 1,
#                 "occasionally": 1,
#                 "tonyarkles": 1,
#                 "particularly": 1,
#                 "nasty": 1,
#                 "involved": 1,
#                 "learning": 1,
#                 "lived": 1,
#                 "mom": 1,
#                 "house": 1,
#                 "computer": 1,
#                 "dad": 1,
#                 "spent": 1,
#                 "correcting": 1,
#                 "habits": 1,
#                 "die": 1,
#                 "x4": 1,
#                 "draw": 1,
#                 "agreed": 1,
#                 "dominikdsgnr": 1,
#                 "desired": 1,
#                 "deal": 1,
#                 "softwrap": 1,
#                 "author": 1,
#                 "reviewers": 1,
#                 "strict": 1,
#                 "Hint": 1,
#                 "wan": 1,
#                 "enforce": 1,
#                 "petosorus": 1,
#                 "160": 1,
#                 "compromise": 1,
#                 "dafaq": 1,
#                 "this_was_a_terrible_idea_but_yolo": 1,
#                 "simple_exprs_are_incomprehensible": 1,
#                 "applications": 1,
#                 "sane": 1,
#                 "mathematician": 1,
#                 "Character": 1,
#                 "succinct": 1,
#                 "chosen": 1,
#                 "accurate": 1,
#                 "extraction": 1,
#                 "pls": 1,
#                 "calculations": 1,
#                 "weapon_translation_worldspace": 1,
#                 "character_translation_worldspace": 1,
#                 "weapon_translation_characterspace": 1,
#                 "characterspace_to_worldspace": 1,
#                 "weapChar": 1,
#                 "charToWorld": 1,
#                 "described": 1,
#                 "guides": 1,
#                 "justifiable": 1,
#                 "apart": 1,
#                 "limited": 1,
#                 "user_input_data_history": 1,
#                 "output_jose_capablanca_filename": 1,
#                 "Highly": 1,
#                 "programs": 1,
#                 "nonetheless": 1,
#                 "aura": 1,
#                 "Print": 1,
#                 "message": 1,
#                 "Aura": 1,
#                 "flair": 1,
#                 "Settings": 1,
#                 "Doc": 1,
#                 "AnsiStyle": 1,
#                 "putStrLnA": 1,
#                 "liftEitherM": 1,
#                 "Error": 1,
#                 "Eff": 1,
#                 "send": 1,
#                 "liftMaybe": 1,
#                 "Slightly": 1,
#                 "extreme": 1,
#                 "bimap": 1,
#                 "fold": 1,
#                 "unzip": 1,
#                 "map": 1,
#                 "fmapEither": 1,
#                 "mapMaybe": 1,
#                 "fmap": 1,
#                 "NES": 1,
#                 "fromNonEmpty": 1,
#                 "NEL": 1,
#                 "nonEmpty": 1,
#                 "FromAUR": 1,
#                 "FromRepo": 1,
#                 "Notice": 1,
#                 "arguments": 1,
#                 "composable": 1,
#                 "Pre": 1,
#                 "Post": 1,
#                 "Intermediate": 1,
#                 "conversion": 1,
#                 "ambiguous": 1,
#                 "decouple": 1,
#                 "exposed": 1,
#                 "dealt": 1,
#                 "past": 1,
#                 "ambiguity": 1,
#                 "clues": 1,
#                 "convert_": 1,
#                 "tells": 1,
#                 "to_shazbot": 1,
#                 "act": 1,
#                 "post_converted_data": 1,
#                 "shaz_filename": 1,
#                 "exclusively": 1,
#                 "convert_post_converted_zapruder_to_shazbot": 1,
#                 "out_another": 1,
#                 "CLI_UTILITY": 1,
#                 "readFromDisk": 1,
#                 "GenerateIntermediateData": 1,
#                 "RecalculateModule": 1,
#                 "flags": 1,
#                 "shazbotUtil": 1,
#                 "RebuildFlags": 1,
#                 "generateShazbot": 1,
#                 "write_to_disk": 1,
#                 "claiming": 1,
#                 "cleanest": 1,
#                 "accumulate": 1,
#                 "lasting": 1,
#                 "party": 1,
#                 "certainly": 1,
#                 "hurt": 1,
#                 "evaned": 1,
#                 "note": 1,
#                 "larger": 1,
#                 "92": 1,
#                 "column": 1,
#                 "measure": 1,
#                 "88": 1,
#                 "differ": 1,
#                 "Handle": 1,
#                 "warxion": 1,
#                 "outside": 1,
#                 "quintus_horatius": 1,
#                 "wewbull": 1,
#                 "OO": 1,
#                 "resurrected": 1,
#                 "member": 1,
#                 "global": 1,
#                 "identifiers": 1,
#                 "perfectly": 1,
#                 "scoped": 1,
#                 "fan": 1,
#                 "embedding": 1,
#                 "Yep": 1,
#                 "projects": 1,
#                 "Vertical": 1,
#                 "horizontal": 1,
#                 "Limiting": 1,
#                 "changer": 1,
#                 "depending": 1,
#                 "spots": 1,
#                 "heathen": 1,
#                 "cutoff": 1,
#                 "editor": 1,
#                 "autoindented": 1,
#                 "extra": 1,
#                 "indented": 1,
#                 "swear": 1,
#                 "straight": 1,
#                 "stone": 1,
#                 "age": 1,
#                 "enable": 1,
#                 "separate": 1,
#                 "setting": 1,
#                 "indenting": 1,
#                 "wrapped": 1,
#                 "decade": 1,
#                 "Thanks": 1,
#                 "suggestion": 1,
#                 "edit": 1,
#                 "groovy": 1,
#                 "Namespace": 1,
#                 "Class": 1,
#                 "thankfully": 1,
#                 "noticed": 1,
#                 "annoy": 1,
#                 "haha": 1,
#                 "annoys": 1,
#                 "verbosity": 1,
#                 "throw": 1,
#                 "format": 1,
#                 "follows": 1,
#                 "whocouldwinaportal": 1,
#                 "bodied": 1,
#                 "adding": 1,
#                 "E": 1,
#                 "java": 1,
#                 "get_": 1,
#                 "asking": 1,
#                 "boilerplate": 1,
#                 "Matty_mathy": 1,
#                 "dragonstorm97": 1,
#                 "placement": 1,
#                 "dagnabbit": 1,
#                 "ardent": 1,
#                 "defender": 1,
#                 "patch": 1,
#                 "configure": 1,
#                 "locally": 1,
#                 "nah": 1,
#                 "years": 1,
#                 "migrating": 1,
#                 "pain": 1,
#                 "tab": 1,
#                 "induces": 1,
#                 "align": 1,
#                 "incredible": 1,
#                 "indentation": 1,
#                 "alignment": 1,
#                 "ShinyHappyREM": 1,
#                 "ftfy": 1,
#                 "Early": 1,
#                 "nicer": 1,
#                 "disappears": 1,
#                 "bless": 1,
#                 "mlud": 1,
#                 "chains": 1,
#                 "deeply": 1,
#                 "ifs": 1,
#                 "argue": 1,
#                 "needing": 1,
#                 "jjolla888": 1,
#                 "Simplicity": 1,
#                 "king": 1,
#                 "Read": 1,
#                 "enjoyed": 1,
#                 "existence": 1,
#                 "fatal": 1,
#                 "unnecessary": 1,
#                 "outlook": 1,
#                 "construct": 1,
#                 "overuse": 1,
#                 "atilaneves": 1,
#                 "assigned": 1,
#                 "pointer": 1,
#                 "contract": 1,
#                 "called": 1,
#                 "callee": 1,
#                 "expects": 1,
#                 "Giving": 1,
#                 "supplying": 1,
#                 "missing": 1,
#                 "semantics": 1,
#                 "clearer": 1,
#                 "filtering": 1,
#                 "optionals": 1,
#                 "convert": 1,
#                 "usages": 1,
#                 "accidental": 1,
#                 "respond": 1,
#                 "representing": 1,
#                 "hardware": 1,
#                 "limbo": 1,
#                 "N": 1,
#                 "available": 1,
#                 "practical": 1,
#                 "register": 1,
#                 "website": 1,
#                 "gives": 1,
#                 "went": 1,
#                 "documenting": 1,
#                 "fields": 1,
#                 "allowed": 1,
#                 "initialized": 1,
#                 "forgetting": 1,
#                 "outcome": 1,
#                 "declare": 1,
#                 "Essentially": 1,
#                 "legal": 1,
#                 "concrete": 1,
#                 "annotate": 1,
#                 "NotNull": 1,
#                 "Nullable": 1,
#                 "variants": 1,
#                 "checkers": 1,
#                 "dereferencing": 1,
#                 "late": 1,
#                 "orElse": 1,
#                 "hunt": 1,
#                 "stack": 1,
#                 "traces": 1,
#                 "caused": 1,
#                 "Oh": 1,
#                 "Collections": 1,
#                 "emptyList": 1,
#                 "friends": 1,
#                 "waste": 1,
#                 "memory": 1,
#                 "reviews": 1,
#                 "book": 1,
#                 "questionalble": 1,
#                 "obscure": 1,
#                 "reinforce": 1,
#                 "narrative": 1,
#                 "Cicero": 1,
#                 "knew": 1,
#                 "rhetoric": 1,
#                 "applied": 1,
#                 "dangerous": 1,
#                 "reflect": 1,
#                 "closely": 1,
#                 "busy": 1,
#                 "inventing": 1,
#                 "crutches": 1,
#                 "sledgehammer": 1,
#                 "utterly": 1,
#                 "unfitting": 1,
#                 "paradigm": 1,
#                 "extend": 1,
#                 "99": 1,
#                 "slegehammering": 1,
#                 "misunderstand": 1,
#                 "communicate": 1,
#                 "invent": 1,
#                 "gave": 1,
#                 "existing": 1,
#                 "words": 1,
#                 "misleading": 1,
#                 "Vocabulary": 1,
#                 "implies": 1,
#                 "deals": 1,
#                 "idioms": 1,
#                 "recognised": 1,
#                 "meet": 1,
#                 "idiom": 1,
#                 "evidently": 1,
#                 "operating": 1,
#                 "YES": 1,
#                 "templated": 1,
#                 "replace": 1,
#                 "library": 1,
#                 "supporting": 1,
#                 "convention": 1,
#                 "configuration": 1,
#                 "SchrodingerSemicolon": 1,
#                 "reminds": 1,
#                 "nightmarish": 1,
#                 "support": 1,
#                 "taken": 1,
#                 "layers": 1,
#                 "chain": 1,
#                 "technically": 1,
#                 "speaking": 1,
#                 "semi": 1,
#                 "monolithic": 1,
#                 "fragments": 1,
#                 "finallytrycatch": 1,
#                 "https": 1,
#                 "blog": 1,
#                 "cleancoder": 1,
#                 "com": 1,
#                 "bob": 1,
#                 "2017": 1,
#                 "02": 1,
#                 "NecessaryComments": 1,
#                 "html": 1,
#                 "Connect_Entrance": 1,
#                 "zhujik": 1,
#                 "Good": 1,
#                 "religiously": 1,
#                 "followed": 1,
#                 "au": 1,
#                 "fait": 1,
#                 "questions": 1,
#                 "POJOs": 1,
#                 "Domain": 1,
#                 "Value": 1,
#                 "Objects": 1,
#                 "API": 1,
#                 "packed": 1,
#                 "pull": 1,
#                 "json": 1,
#                 "Brian": 1,
#                 "role": 1,
#                 "assign": 1,
#                 "manipulate": 1,
#                 "keeps": 1,
#                 "ES6": 1,
#                 "render": 1,
#                 "objects": 1,
#                 "defining": 1,
#                 "differently": 1,
#                 "connected": 1,
#                 "mcarabolante": 1,
#                 "domains": 1,
#                 "roles": 1,
#                 "isAdmin": 1,
#                 "centralize": 1,
#                 "UserService": 1,
#                 "RoleService": 1,
#                 "MostLikelyIrrelevant": 1,
#                 "Nice": 1,
#                 "51": 1,
#                 "SuperMancho": 1,
#                 "Commented": 1,
#                 "dig": 1,
#                 "random": 1,
#                 "Neelsl": 1,
#                 "basically": 1,
#                 "Clean": 1,
#                 "Bob": 1,
#                 "Guard": 1,
#                 "clauses": 1,
#                 "wrapping": 1,
#                 "rethink": 1,
#                 "accept": 1,
#                 "regardless": 1,
#                 "throws": 1,
#                 "improves": 1,
#                 "success": 1,
#                 "complicated_answer": 1,
#                 "readably": 1,
#                 "integer": 1,
#                 "containing": 1,
#                 "keyboardhack": 1,
#                 "contrast": 1,
#                 "mind": 1,
#                 "constrains": 1,
#                 "flow": 1,
#                 "Look": 1,
#                 "u": 1,
#                 "Imagine": 1,
#                 "client": 1,
#                 "wants": 1,
#                 "Instead": 1,
#                 "printing": 1,
#                 "automatically": 1,
#                 "rest": 1
#             },
#             "times": {
#                 "vocab": 0.0021,
#                 "words": 0.0087
#             }
#         }
#     }
# }

# %% [markdown]
# ## Profiler Type

# %% [markdown]
# It should be noted, in addition to reading the input data from text files, DataProfiler allows the input data as a pandas dataframe, a pandas series, a list, and Data objects (when an unstructured format is selected) if the Profiler is explicitly chosen as unstructured.

# %%
# run data profiler and get the report
import pandas as pd
data = dp.Data(os.path.join(data_path, "csv/SchoolDataSmall.csv"), options={"data_format": "records"})
profile = dp.Profiler(data, profiler_type='unstructured')

report  = profile.report(report_options={"output_format":"pretty"})
print(json.dumps(report, indent=4))
# Out:
# Finding the empty lines in the data...
# Calculating the statistics...
# WARNING:tensorflow:5 out of the last 189 calls to <function recreate_function.<locals>.restored_function_body at 0x15ca90ca0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# {
#     "global_stats": {
#         "samples_used": 1000,
#         "empty_line_count": 0,
#         "file_type": "csv",
#         "encoding": "utf-8"
#     },
#     "data_stats": {
#         "data_label": {
#             "entity_counts": {
#                 "word_level": {
#                     "UNKNOWN": 14481,
#                     "INTEGER": 1686,
#                     "URL": 1960,
#                     "FLOAT": 2009,
#                     "US_STATE": 431,
#                     "PERSON": 1644,
#                     "PHONE_NUMBER": 19,
#                     "BAN": 4,
#                     "QUANTITY": 3,
#                     "ADDRESS": 51,
#                     "HASH_OR_KEY": 11,
#                     "DRIVERS_LICENSE": 233,
#                     "DATE": 1,
#                     "ORDINAL": 6,
#                     "IPV6": 1,
#                     "CREDIT_CARD": 1
#                 },
#                 "true_char_level": {
#                     "UNKNOWN": 129197,
#                     "INTEGER": 8552,
#                     "US_STATE": 3673,
#                     "PERSON": 24361,
#                     "URL": 64836,
#                     "FLOAT": 19336,
#                     "DRIVERS_LICENSE": 2847,
#                     "DATE": 48,
#                     "PHONE_NUMBER": 432,
#                     "ADDRESS": 784,
#                     "BAN": 103,
#                     "QUANTITY": 32,
#                     "HASH_OR_KEY": 504,
#                     "PAD": 24,
#                     "IPV6": 12,
#                     "DATETIME": 3,
#                     "ORDINAL": 56,
#                     "EMAIL_ADDRESS": 39,
#                     "CREDIT_CARD": 15,
#                     "TIME": 6,
#                     "SSN": 1
#                 },
#                 "postprocess_char_level": {
#                     "UNKNOWN": 135023,
#                     "INTEGER": 7733,
#                     "URL": 63931,
#                     "FLOAT": 19309,
#                     "US_STATE": 3493,
#                     "PERSON": 22197,
#                     "PHONE_NUMBER": 190,
#                     "BAN": 34,
#                     "QUANTITY": 15,
#                     "ADDRESS": 425,
#                     "HASH_OR_KEY": 133,
#                     "DRIVERS_LICENSE": 2330,
#                     "DATE": 13,
#                     "ORDINAL": 29,
#                     "IPV6": 3,
#                     "CREDIT_CARD": 3
#                 }
#             },
#             "times": {
#                 "data_labeler_predict": 10.9318
#             }
#         },
#         "statistics": {
#             "vocab": "['q', 'x', 'H', '~', 'Y', ... , '/', '6', 'E', 'p', 'd']",
#             "words": "['OPEID6', 'INSTNM', 'ZIP', ... , 'rockford', '270639', '019536']",
#             "word_count": {
#                 "edu": 1670,
#                 "www": 1387,
#                 "College": 1155,
#                 "Colleges": 972,
#                 "PrivacySuppressed": 964,
#                 "NULL": 887,
#                 "Commission": 871,
#                 "University": 801,
#                 "https": 584,
#                 "Schools": 547,
#                 "Association": 475,
#                 "Community": 317,
#                 "Accrediting": 298,
#                 "Western": 270,
#                 "calculator": 268,
#                 "Higher": 264,
#                 "net": 243,
#                 "State": 231,
#                 "npcalc": 218,
#                 "htm": 218,
#                 "price": 214,
#                 "Southern": 211,
#                 "com": 206,
#                 "Learning": 205,
#                 "Career": 187,
#                 "aid": 185,
#                 "financial": 167,
#                 "School": 166,
#                 "34": 158,
#                 "Technical": 153,
#                 "Institute": 151,
#                 "npc": 151,
#                 "33": 148,
#                 "Education": 148,
#                 "Junior": 136,
#                 "Senior": 135,
#                 "41": 124,
#                 "Beauty": 101,
#                 "aspx": 98,
#                 "California": 98,
#                 "admissions": 97,
#                 "Sciences": 96,
#                 "National": 95,
#                 "Florida": 94,
#                 "Arts": 91,
#                 "117": 89,
#                 "87": 83,
#                 "html": 81,
#                 "San": 81,
#                 "Academy": 80,
#                 "misweb": 80,
#                 "cccco": 80,
#                 "37": 77,
#                 "118": 76,
#                 "30": 71,
#                 "tuition": 70,
#                 "32": 69,
#                 "122": 69,
#                 "Arkansas": 69,
#                 "Council": 67,
#                 "org": 62,
#                 "38": 60,
#                 "39": 60,
#                 "Occupational": 58,
#                 "index": 53,
#                 "Seminary": 53,
#                 "West": 50,
#                 "Colorado": 50,
#                 "Theological": 49,
#                 "84": 48,
#                 "studentaidcalculator": 47,
#                 "Design": 47,
#                 "81": 47,
#                 "88": 46,
#                 "New": 45,
#                 "Chicago": 45,
#                 "financialaid": 44,
#                 "121": 42,
#                 "80": 42,
#                 "finaid": 41,
#                 "Valley": 41,
#                 "student": 41,
#                 "cost": 40,
#                 "City": 40,
#                 "Illinois": 39,
#                 "North": 38,
#                 "Los": 38,
#                 "40": 38,
#                 "survey": 37,
#                 "England": 37,
#                 "72": 37,
#                 "Health": 35,
#                 "36": 35,
#                 "Angeles": 35,
#                 "Georgia": 35,
#                 "35": 34,
#                 "82": 34,
#                 "Pacific": 33,
#                 "Center": 33,
#                 "Hair": 32,
#                 "American": 32,
#                 "netprice": 31,
#                 "netpricecalculator": 31,
#                 "Arizona": 31,
#                 "NetPriceCalculator": 30,
#                 "college": 30,
#                 "St": 30,
#                 "42": 30,
#                 "86": 29,
#                 "collegeboard": 29,
#                 "119": 29,
#                 "fees": 28,
#                 "Northwest": 28,
#                 "app": 28,
#                 "Inc": 28,
#                 "Art": 28,
#                 "Diego": 28,
#                 "Technology": 28,
#                 "International": 28,
#                 "Santa": 28,
#                 "Christian": 27,
#                 "Central": 27,
#                 "States": 27,
#                 "Campus": 27,
#                 "28": 27,
#                 "27": 26,
#                 "Alabama": 25,
#                 "costs": 25,
#                 "85": 25,
#                 "71": 25,
#                 "South": 25,
#                 "Pages": 25,
#                 "92": 25,
#                 "104": 25,
#                 "Atlanta": 25,
#                 "Cosmetology": 24,
#                 "John": 24,
#                 "services": 23,
#                 "paying": 23,
#                 "89": 23,
#                 "www2": 22,
#                 "php": 22,
#                 "Nursing": 22,
#                 "admission": 22,
#                 "Trinity": 22,
#                 "Tech": 21,
#                 "Francisco": 21,
#                 "students": 20,
#                 "Baptist": 20,
#                 "90": 20,
#                 "consumer": 19,
#                 "111": 19,
#                 "District": 19,
#                 "default": 19,
#                 "River": 19,
#                 "Middle": 19,
#                 "Law": 19,
#                 "25": 19,
#                 "Miami": 19,
#                 "83": 19,
#                 "hawaii": 19,
#                 "files": 18,
#                 "112": 18,
#                 "Graduate": 18,
#                 "Lincoln": 18,
#                 "Denver": 18,
#                 "Connecticut": 18,
#                 "Bible": 17,
#                 "East": 17,
#                 "Park": 17,
#                 "Beach": 17,
#                 "105": 17,
#                 "26": 17,
#                 "Net": 16,
#                 "Empire": 16,
#                 "Phoenix": 16,
#                 "Eastern": 16,
#                 "Medical": 16,
#                 "Fort": 16,
#                 "Paul": 16,
#                 "Lake": 16,
#                 "Concorde": 16,
#                 "ccc": 16,
#                 "Calculator": 15,
#                 "75": 15,
#                 "U": 15,
#                 "County": 15,
#                 "Salon": 15,
#                 "csu": 15,
#                 "Coast": 15,
#                 "Saint": 15,
#                 "information": 14,
#                 "54": 14,
#                 "Alaska": 14,
#                 "Universities": 14,
#                 "Carrington": 14,
#                 "WWW": 14,
#                 "Mitchell": 14,
#                 "Medicine": 14,
#                 "attend": 14,
#                 "116": 14,
#                 "campus": 14,
#                 "29": 14,
#                 "Idaho": 14,
#                 "colleges": 14,
#                 "George": 13,
#                 "0001": 13,
#                 "Bureau": 13,
#                 "Tucson": 13,
#                 "empire": 13,
#                 "EDU": 13,
#                 "Rock": 13,
#                 "93": 13,
#                 "Northeastern": 13,
#                 "120": 13,
#                 "undergraduate": 13,
#                 "calstate": 13,
#                 "Columbia": 13,
#                 "Orange": 13,
#                 "Lewis": 13,
#                 "Urbana": 13,
#                 "31": 12,
#                 "C": 12,
#                 "Wallace": 12,
#                 "Price": 12,
#                 "Jacksonville": 12,
#                 "Mesa": 12,
#                 "0": 12,
#                 "enroll": 12,
#                 "91": 12,
#                 "Professional": 12,
#                 "tcc": 12,
#                 "CET": 12,
#                 "cetweb": 12,
#                 "Business": 12,
#                 "Hawaii": 12,
#                 "financial_aid": 11,
#                 "66": 11,
#                 "school": 11,
#                 "Little": 11,
#                 "94": 11,
#                 "Barbara": 11,
#                 "73": 11,
#                 "FIDM": 11,
#                 "Npc": 11,
#                 "Nazarene": 11,
#                 "21": 11,
#                 "cfm": 10,
#                 "net_price_calculator": 10,
#                 "content": 10,
#                 "NetPrice": 10,
#                 "110": 10,
#                 "carrington": 10,
#                 "La": 10,
#                 "Cortiva": 10,
#                 "resources": 10,
#                 "Mountain": 10,
#                 "pages": 10,
#                 "paulmitchell": 10,
#                 "Transnational": 10,
#                 "UC": 10,
#                 "Theology": 10,
#                 "Cost": 10,
#                 "Southwestern": 10,
#                 "Thomas": 10,
#                 "Hartford": 10,
#                 "Savannah": 10,
#                 "wp": 9,
#                 "attendance": 9,
#                 "Main": 9,
#                 "AZ": 9,
#                 "Prescott": 9,
#                 "Northern": 9,
#                 "NPC": 9,
#                 "netpricecalc": 9,
#                 "sites": 9,
#                 "Springs": 9,
#                 "Spa": 9,
#                 "Mid": 9,
#                 "Culture": 9,
#                 "Conservatory": 9,
#                 "Sacramento": 9,
#                 "Joaquin": 9,
#                 "Northwestern": 9,
#                 "77": 9,
#                 "Tampa": 9,
#                 "157": 9,
#                 "Boise": 9,
#                 "F": 8,
#                 "B": 8,
#                 "United": 8,
#                 "Charles": 8,
#                 "cortiva": 8,
#                 "Glendale": 8,
#                 "info": 8,
#                 "Freshman": 8,
#                 "Studies": 8,
#                 "Irvine": 8,
#                 "CC": 8,
#                 "Fashion": 8,
#                 "43": 8,
#                 "Holy": 8,
#                 "Life": 8,
#                 "concorde": 8,
#                 "myconcorde": 8,
#                 "lincolntech": 8,
#                 "ct": 8,
#                 "Massage": 8,
#                 "Washington": 8,
#                 "orangetechcollege": 8,
#                 "74": 7,
#                 "Montgomery": 7,
#                 "J": 7,
#                 "Jefferson": 7,
#                 "Northeast": 7,
#                 "netcalc": 7,
#                 "76": 7,
#                 "America": 7,
#                 "Univ": 7,
#                 "Architecture": 7,
#                 "Universal": 7,
#                 "scholarships": 7,
#                 "Pima": 7,
#                 "Smith": 7,
#                 "Oriental": 7,
#                 "Bakersfield": 7,
#                 "Cal": 7,
#                 "Bernardino": 7,
#                 "Hills": 7,
#                 "Fresno": 7,
#                 "Riverside": 7,
#                 "Jose": 7,
#                 "El": 7,
#                 "91711": 7,
#                 "Dominican": 7,
#                 "Sierra": 7,
#                 "FinancialAid": 7,
#                 "Regis": 7,
#                 "Wesleyan": 7,
#                 "Delaware": 7,
#                 "Atlantic": 7,
#                 "Palm": 7,
#                 "Petersburg": 7,
#                 "Find": 7,
#                 "Danville": 7,
#                 "Champaign": 7,
#                 "Rockford": 7,
#                 "Birmingham": 6,
#                 "Auburn": 6,
#                 "southuniversity": 6,
#                 "cms": 6,
#                 "Financial": 6,
#                 "calc": 6,
#                 "61": 6,
#                 "114": 6,
#                 "2": 6,
#                 "Embry": 6,
#                 "Riddle": 6,
#                 "Aeronautical": 6,
#                 "Grand": 6,
#                 "disclosures": 6,
#                 "Ridge": 6,
#                 "cosmetology": 6,
#                 "Regional": 6,
#                 "uploads": 6,
#                 "10": 6,
#                 "Bellus": 6,
#                 "Pomona": 6,
#                 "Fullerton": 6,
#                 "LA": 6,
#                 "estimator": 6,
#                 "Loma": 6,
#                 "23328": 6,
#                 "shtml": 6,
#                 "Science": 6,
#                 "Concordia": 6,
#                 "noellevitz": 6,
#                 "Claremont": 6,
#                 "Hollywood": 6,
#                 "Merchandising": 6,
#                 "education": 6,
#                 "Union": 6,
#                 "Success": 6,
#                 "Pierce": 6,
#                 "Mt": 6,
#                 "Training": 6,
#                 "de": 6,
#                 "Shasta": 6,
#                 "Delta": 6,
#                 "sbbcollege": 6,
#                 "Marshall": 6,
#                 "Ventura": 6,
#                 "108": 6,
#                 "Talmudic": 6,
#                 "Boulder": 6,
#                 "Aurora": 6,
#                 "Jr": 6,
#                 "Accreditation": 6,
#                 "bor": 6,
#                 "Branford": 6,
#                 "commnet": 6,
#                 "Net_Price_Calculator": 6,
#                 "Pinellas": 6,
#                 "Johns": 6,
#                 "Clark": 6,
#                 "Gwinnett": 6,
#                 "Cannella": 6,
#                 "cannellabeautyschools": 6,
#                 "Selma": 5,
#                 "Bibical": 5,
#                 "Educaiton": 5,
#                 "secure": 5,
#                 "future": 5,
#                 "95": 5,
#                 "apps": 5,
#                 "H": 5,
#                 "149": 5,
#                 "UA": 5,
#                 "Az": 5,
#                 "Southwest": 5,
#                 "Wright": 5,
#                 "financing": 5,
#                 "calculators": 5,
#                 "LLC": 5,
#                 "web": 5,
#                 "Beebe": 5,
#                 "programs": 5,
#                 "Brown": 5,
#                 "Rivers": 5,
#                 "Hope": 5,
#                 "Shorter": 5,
#                 "20Price": 5,
#                 "Acupuncture": 5,
#                 "Alameda": 5,
#                 "losrios": 5,
#                 "92101": 5,
#                 "welcome": 5,
#                 "CSU": 5,
#                 "Long": 5,
#                 "Berkeley": 5,
#                 "Psychology": 5,
#                 "california": 5,
#                 "Crafton": 5,
#                 "Independent": 5,
#                 "Fielding": 5,
#                 "Golden": 5,
#                 "gov": 5,
#                 "L": 5,
#                 "Otis": 5,
#                 "Point": 5,
#                 "CU": 5,
#                 "Pueblo": 5,
#                 "Porter": 5,
#                 "Chester": 5,
#                 "Stone": 5,
#                 "asp": 5,
#                 "Rollins": 5,
#                 "Bethune": 5,
#                 "Cookman": 5,
#                 "Chipola": 5,
#                 "Daytona": 5,
#                 "florida": 5,
#                 "Hospital": 5,
#                 "fl": 5,
#                 "office": 5,
#                 "NetPriceCalc": 5,
#                 "Robert": 5,
#                 "Esthetics": 5,
#                 "Columbus": 5,
#                 "Young": 5,
#                 "Honolulu": 5,
#                 "Mr": 5,
#                 "Blessing": 5,
#                 "60605": 5,
#                 "Champagne": 5,
#                 "Land": 5,
#                 "Moody": 5,
#                 "Moraine": 5,
#                 "np": 4,
#                 "Chattahoochee": 4,
#                 "Enterprise": 4,
#                 "Coastal": 4,
#                 "Gadsden": 4,
#                 "Aid": 4,
#                 "Herzing": 4,
#                 "herzing": 4,
#                 "Drake": 4,
#                 "Uploads": 4,
#                 "Judson": 4,
#                 "departments": 4,
#                 "alaska": 4,
#                 "Southeast": 4,
#                 "Charter": 4,
#                 "CollegeAmerica": 4,
#                 "Flagstaff": 4,
#                 "collegeamerica": 4,
#                 "Platt": 4,
#                 "ASU": 4,
#                 "Avalon": 4,
#                 "avalon": 4,
#                 "locations": 4,
#                 "assets": 4,
#                 "uti": 4,
#                 "Scottsdale": 4,
#                 "pmi": 4,
#                 "Rio": 4,
#                 "Arthur": 4,
#                 "arthursbeautycollege": 4,
#                 "jacksonville": 4,
#                 "Black": 4,
#                 "pay": 4,
#                 "Crowley": 4,
#                 "crc": 4,
#                 "1099": 4,
#                 "Barber": 4,
#                 "Dramatic": 4,
#                 "cloud": 4,
#                 "Associated": 4,
#                 "bellusacademy": 4,
#                 "Lutheran": 4,
#                 "Polytechnic": 4,
#                 "Stanislaus": 4,
#                 "docs": 4,
#                 "Van": 4,
#                 "Nuys": 4,
#                 "Students": 4,
#                 "94709": 4,
#                 "Citrus": 4,
#                 "Heights": 4,
#                 "Visalia": 4,
#                 "fidm": 4,
#                 "apply": 4,
#                 "20University": 4,
#                 "Harvey": 4,
#                 "Modesto": 4,
#                 "Monica": 4,
#                 "Kennedy": 4,
#                 "79": 4,
#                 "Chiropractic": 4,
#                 "Mission": 4,
#                 "Loyola": 4,
#                 "Marymount": 4,
#                 "Lyle": 4,
#                 "lylescolleges": 4,
#                 "MTI": 4,
#                 "Merritt": 4,
#                 "Monterey": 4,
#                 "Mary": 4,
#                 "nu": 4,
#                 "Adrian": 4,
#                 "north": 4,
#                 "48": 4,
#                 "Palo": 4,
#                 "59": 4,
#                 "ed": 4,
#                 "Miramar": 4,
#                 "William": 4,
#                 "Jones": 4,
#                 "Grove": 4,
#                 "King": 4,
#                 "Junction": 4,
#                 "Bel": 4,
#                 "Rea": 4,
#                 "Aeronautics": 4,
#                 "CO": 4,
#                 "Colo": 4,
#                 "Rockies": 4,
#                 "Emily": 4,
#                 "Griffith": 4,
#                 "Metropolitan": 4,
#                 "Morgan": 4,
#                 "NE": 4,
#                 "Otero": 4,
#                 "Altierus": 4,
#                 "Thornton": 4,
#                 "altierus": 4,
#                 "Montessori": 4,
#                 "Intellitec": 4,
#                 "intellitec": 4,
#                 "porterchester": 4,
#                 "Gateway": 4,
#                 "Wesley": 4,
#                 "Catholic": 4,
#                 "Immaculate": 4,
#                 "Conception": 4,
#                 "Fla": 4,
#                 "Charlotte": 4,
#                 "Agricultural": 4,
#                 "finance": 4,
#                 "Fl": 4,
#                 "artinstitutes": 4,
#                 "miami": 4,
#                 "Manatee": 4,
#                 "Educational": 4,
#                 "Dade": 4,
#                 "Southeastern": 4,
#                 "Vincent": 4,
#                 "Leo": 4,
#                 "Vianney": 4,
#                 "USF": 4,
#                 "Westside": 4,
#                 "collegecostcalculator": 4,
#                 "Interactive": 4,
#                 "ict": 4,
#                 "Albany": 4,
#                 "atlanta": 4,
#                 "Area": 4,
#                 "30314": 4,
#                 "Morehouse": 4,
#                 "Falls": 4,
#                 "Valdosta": 4,
#                 "UH": 4,
#                 "Maui": 4,
#                 "Travel": 4,
#                 "Tricoci": 4,
#                 "tricociuniversity": 4,
#                 "Bradley": 4,
#                 "bradley": 4,
#                 "Professionals": 4,
#                 "hairpros": 4,
#                 "Forest": 4,
#                 "Huntsville": 3,
#                 "13039": 3,
#                 "location": 3,
#                 "Faulkner": 3,
#                 "nbc": 3,
#                 "Hanceville": 3,
#                 "20": 3,
#                 "Content": 3,
#                 "20College": 3,
#                 "Calhoun": 3,
#                 "Lurleen": 3,
#                 "nw": 3,
#                 "nacc": 3,
#                 "Hill": 3,
#                 "Trenholm": 3,
#                 "3199": 3,
#                 "Sports": 3,
#                 "bscc": 3,
#                 "Vocational": 3,
#                 "page": 3,
#                 "21006": 3,
#                 "Apollo": 3,
#                 "Tempe": 3,
#                 "arizona": 3,
#                 "university": 3,
#                 "Visual": 3,
#                 "Cochise": 3,
#                 "86301": 3,
#                 "prescott": 3,
#                 "erau": 3,
#                 "52": 3,
#                 "Refrigeration": 3,
#                 "program": 3,
#                 "yc": 3,
#                 "forms": 3,
#                 "72202": 3,
#                 "ICS": 3,
#                 "72114": 3,
#                 "1000": 3,
#                 "Cossatot": 3,
#                 "2204": 3,
#                 "Leon": 3,
#                 "prospective": 3,
#                 "Ozarks": 3,
#                 "Phillips": 3,
#                 "2019": 3,
#                 "Pulaski": 3,
#                 "Rich": 3,
#                 "uafs": 3,
#                 "20Calculator": 3,
#                 "COM": 3,
#                 "new": 3,
#                 "90028": 3,
#                 "94704": 3,
#                 "Film": 3,
#                 "AFI": 3,
#                 "aidcalc": 3,
#                 "95841": 3,
#                 "91103": 3,
#                 "ruffalonl": 3,
#                 "1299": 3,
#                 "Barstow": 3,
#                 "Chula": 3,
#                 "Vista": 3,
#                 "Bethesda": 3,
#                 "92801": 3,
#                 "undergrad": 3,
#                 "Hastings": 3,
#                 "92831": 3,
#                 "Bay": 3,
#                 "Davis": 3,
#                 "Cruz": 3,
#                 "CCU": 3,
#                 "Maritime": 3,
#                 "1899": 3,
#                 "institute": 3,
#                 "Cogswell": 3,
#                 "1197": 3,
#                 "Cosumnes": 3,
#                 "Theatre": 3,
#                 "Desert": 3,
#                 "Diablo": 3,
#                 "1598": 3,
#                 "11112": 3,
#                 "Feather": 3,
#                 "124": 3,
#                 "20Students": 3,
#                 "enrollment": 3,
#                 "gotobeautyschool": 3,
#                 "salonsuccessacademy": 3,
#                 "Mudd": 3,
#                 "Names": 3,
#                 "1699": 3,
#                 "95207": 3,
#                 "Hairdressing": 3,
#                 "Cajon": 3,
#                 "Verne": 3,
#                 "Harbor": 3,
#                 "masters": 3,
#                 "dhs": 3,
#                 "Medanos": 3,
#                 "Menlo": 3,
#                 "Merced": 3,
#                 "Mills": 3,
#                 "getting": 3,
#                 "started": 3,
#                 "1599": 3,
#                 "Jacinto": 3,
#                 "Music": 3,
#                 "Continuing": 3,
#                 "westcollege": 3,
#                 "Pasadena": 3,
#                 "otis": 3,
#                 "Management": 3,
#                 "Ministry": 3,
#                 "Oaks": 3,
#                 "Pepperdine": 3,
#                 "Pitzer": 3,
#                 "96003": 3,
#                 "home": 3,
#                 "nces": 3,
#                 "tiu": 3,
#                 "Simpson": 3,
#                 "Solano": 3,
#                 "Vanguard": 3,
#                 "Optometry": 3,
#                 "Bar": 3,
#                 "Huntington": 3,
#                 "5698": 3,
#                 "1617": 3,
#                 "Westminster": 3,
#                 "Yeshiva": 3,
#                 "Advanced": 3,
#                 "Rabbinical": 3,
#                 "Anschutz": 3,
#                 "Spartan": 3,
#                 "colorado": 3,
#                 "aurora": 3,
#                 "Mines": 3,
#                 "103": 3,
#                 "JC": 3,
#                 "1499": 3,
#                 "Rocky": 3,
#                 "Teacher": 3,
#                 "Pickens": 3,
#                 "Asnuntuck": 3,
#                 "Goodwin": 3,
#                 "7303": 3,
#                 "west": 3,
#                 "hartford": 3,
#                 "Dawn": 3,
#                 "19901": 3,
#                 "Pontifical": 3,
#                 "Faculty": 3,
#                 "Gallaudet": 3,
#                 "Georgetown": 3,
#                 "washington": 3,
#                 "32114": 3,
#                 "Lynn": 3,
#                 "Albizu": 3,
#                 "FL": 3,
#                 "Flagler": 3,
#                 "Seminoles": 3,
#                 "Aviation": 3,
#                 "academy": 3,
#                 "Myers": 3,
#                 "Loraines": 3,
#                 "UserFiles": 3,
#                 "Servers": 3,
#                 "Server_86919": 3,
#                 "File": 3,
#                 "Consumer_Information": 3,
#                 "Orlando": 3,
#                 "Pensacola": 3,
#                 "Clearwater": 3,
#                 "myptc": 3,
#                 "Polk": 3,
#                 "Locklin": 3,
#                 "Ringling": 3,
#                 "Suncoast": 3,
#                 "Seminole": 3,
#                 "Haney": 3,
#                 "htc": 3,
#                 "30310": 3,
#                 "30309": 3,
#                 "Court": 3,
#                 "Reporting": 3,
#                 "Dalton": 3,
#                 "administration": 3,
#                 "30303": 3,
#                 "Radiologic": 3,
#                 "Gordon": 3,
#                 "Funeral": 3,
#                 "Service": 3,
#                 "life": 3,
#                 "Oglethorpe": 3,
#                 "Harris": 3,
#                 "Hilo": 3,
#                 "Manoa": 3,
#                 "honolulu": 3,
#                 "Kapiolani": 3,
#                 "Kauai": 3,
#                 "Leeward": 3,
#                 "Oahu": 3,
#                 "Windward": 3,
#                 "46": 3,
#                 "60602": 3,
#                 "60604": 3,
#                 "Augustana": 3,
#                 "Rieman": 3,
#                 "62305": 3,
#                 "cbs_disclosures": 3,
#                 "Hanover": 3,
#                 "Capri": 3,
#                 "60615": 3,
#                 "Coyne": 3,
#                 "61832": 3,
#                 "G": 3,
#                 "Skin": 3,
#                 "Olney": 3,
#                 "Name": 3,
#                 "MacCormac": 3,
#                 "MacMurray": 3,
#                 "McHenry": 3,
#                 "Niles": 3,
#                 "Morris": 3,
#                 "aamu": 2,
#                 "1052": 2,
#                 "uab": 2,
#                 "Amridge": 2,
#                 "36117": 2,
#                 "amridgeuniversity": 2,
#                 "uah": 2,
#                 "alasu": 2,
#                 "0100": 2,
#                 "ua": 2,
#                 "cacc": 2,
#                 "Athens": 2,
#                 "athens": 2,
#                 "aum": 2,
#                 "current": 2,
#                 "auburn": 2,
#                 "freshman": 2,
#                 "bsc": 2,
#                 "fp": 2,
#                 "cv": 2,
#                 "montgomery": 2,
#                 "escc": 2,
#                 "2698": 2,
#                 "coastalalabama": 2,
#                 "faulkner": 2,
#                 "gadsdenstate": 2,
#                 "Beginning": 2,
#                 "nbccosmetology": 2,
#                 "Dothan": 2,
#                 "wallace": 2,
#                 "wallacestate": 2,
#                 "5699": 2,
#                 "wccs": 2,
#                 "9621": 2,
#                 "Huntingdon": 2,
#                 "huntingdon": 2,
#                 "Heritage": 2,
#                 "hcu": 2,
#                 "drakestate": 2,
#                 "Ingram": 2,
#                 "istc": 2,
#                 "jsu": 2,
#                 "jeffersonstate": 2,
#                 "calhoun": 2,
#                 "36756": 2,
#                 "judson": 2,
#                 "Lawson": 2,
#                 "1717": 2,
#                 "lawsonstate": 2,
#                 "uwa": 2,
#                 "1418": 2,
#                 "lbwcc": 2,
#                 "Marion": 2,
#                 "Military": 2,
#                 "marionmilitary": 2,
#                 "Miles": 2,
#                 "miles": 2,
#                 "Mobile": 2,
#                 "umobile": 2,
#                 "Montevallo": 2,
#                 "montevallo": 2,
#                 "Shoals": 2,
#                 "nwscc": 2,
#                 "scc": 2,
#                 "1033": 2,
#                 "Oakwood": 2,
#                 "oakwood": 2,
#                 "Reid": 2,
#                 "images": 2,
#                 "ReidStateTech": 2,
#                 "Bishop": 2,
#                 "bishop": 2,
#                 "Samford": 2,
#                 "samford": 2,
#                 "selmauniversity": 2,
#                 "Shelton": 2,
#                 "sheltonstate": 2,
#                 "Snead": 2,
#                 "snead": 2,
#                 "0002": 2,
#                 "southalabama": 2,
#                 "Spring": 2,
#                 "shc": 2,
#                 "Springhill": 2,
#                 "Stillman": 2,
#                 "stillman": 2,
#                 "Talladega": 2,
#                 "talladega": 2,
#                 "Councill": 2,
#                 "trenholmstate": 2,
#                 "Troy": 2,
#                 "troy": 2,
#                 "Tuskegee": 2,
#                 "tuskegee": 2,
#                 "ussa": 2,
#                 "Bevill": 2,
#                 "Anchorage": 2,
#                 "99508": 2,
#                 "uaa": 2,
#                 "akbible": 2,
#                 "Fairbanks": 2,
#                 "uaf": 2,
#                 "64": 2,
#                 "1065": 2,
#                 "uas": 2,
#                 "58": 2,
#                 "134": 2,
#                 "alaskapacific": 2,
#                 "avtec": 2,
#                 "chartercollege": 2,
#                 "alaskacareercollege": 2,
#                 "85716": 2,
#                 "85051": 2,
#                 "85210": 2,
#                 "85745": 2,
#                 "85712": 2,
#                 "arizonaacademy": 2,
#                 "Automotive": 2,
#                 "aai": 2,
#                 "Brookline": 2,
#                 "85021": 2,
#                 "brooklinecollege": 2,
#                 "asu": 2,
#                 "azwestern": 2,
#                 "Yuma": 2,
#                 "85721": 2,
#                 "suva": 2,
#                 "centralaz": 2,
#                 "Italy": 2,
#                 "charlesofitaly": 2,
#                 "cochise": 2,
#                 "10542": 2,
#                 "Chandler": 2,
#                 "eac": 2,
#                 "Financial_Aid": 2,
#                 "109": 2,
#                 "1479": 2,
#                 "Taliesin": 2,
#                 "taliesin": 2,
#                 "maricopa": 2,
#                 "Canyon": 2,
#                 "gcu": 2,
#                 "GateWay": 2,
#                 "85034": 2,
#                 "gatewaycc": 2,
#                 "mesacc": 2,
#                 "Mohave": 2,
#                 "1238": 2,
#                 "mohave": 2,
#                 "Motorcycle": 2,
#                 "Mechanics": 2,
#                 "Division": 2,
#                 "MMI": 2,
#                 "Dine": 2,
#                 "dinecollege": 2,
#                 "nau": 2,
#                 "Northland": 2,
#                 "Pioneer": 2,
#                 "Ottawa": 2,
#                 "ottawa": 2,
#                 "phoenixcollege": 2,
#                 "massage": 2,
#                 "1275": 2,
#                 "pima": 2,
#                 "22171": 2,
#                 "Albuquerque": 2,
#                 "106": 2,
#                 "5452": 2,
#                 "1816": 2,
#                 "refrigerationschool": 2,
#                 "Salado": 2,
#                 "85281": 2,
#                 "TuitionCalculator": 2,
#                 "Roberto": 2,
#                 "Venn": 2,
#                 "Luthiery": 2,
#                 "roberto": 2,
#                 "venn": 2,
#                 "scottsdalecc": 2,
#                 "business": 2,
#                 "southmountaincc": 2,
#                 "arizonachristian": 2,
#                 "UTI": 2,
#                 "9459": 2,
#                 "NW": 2,
#                 "Yavapai": 2,
#                 "ualr": 2,
#                 "1109": 2,
#                 "72205": 2,
#                 "uams": 2,
#                 "arkansasbaptist": 2,
#                 "arkbeautyschool": 2,
#                 "72801": 2,
#                 "Lyon": 2,
#                 "lyon": 2,
#                 "jnz": 2,
#                 "portlet": 2,
#                 "Barbering": 2,
#                 "arkansascollegeofbarbering": 2,
#                 "72901": 2,
#                 "1108": 2,
#                 "uark": 2,
#                 "Pine": 2,
#                 "Bluff": 2,
#                 "uapb": 2,
#                 "asub": 2,
#                 "astate": 2,
#                 "1089": 2,
#                 "atu": 2,
#                 "Monticello": 2,
#                 "uamont": 2,
#                 "bhclr": 2,
#                 "accounts": 2,
#                 "blackrivertech": 2,
#                 "uca": 2,
#                 "cbc": 2,
#                 "cccua": 2,
#                 "7044": 2,
#                 "72335": 2,
#                 "crti": 2,
#                 "tec": 2,
#                 "ar": 2,
#                 "id": 2,
#                 "Vocations": 2,
#                 "easterncollege": 2,
#                 "Imagine": 2,
#                 "Partner": 2,
#                 "littlerock": 2,
#                 "Batesville": 2,
#                 "uaccb": 2,
#                 "Harding": 2,
#                 "harding": 2,
#                 "Henderson": 2,
#                 "hsu": 2,
#                 "Hendrix": 2,
#                 "hendrix": 2,
#                 "PriceCalculator": 2,
#                 "Hot": 2,
#                 "hotspringsbeautycollege": 2,
#                 "71603": 2,
#                 "jrmc": 2,
#                 "jbu": 2,
#                 "72764": 2,
#                 "7128": 2,
#                 "beautynwa": 2,
#                 "academysalonspa": 2,
#                 "asumidsouth": 2,
#                 "22285": 2,
#                 "anc": 2,
#                 "Tyler": 2,
#                 "newtylerbarbercollege": 2,
#                 "northark": 2,
#                 "Ouachita": 2,
#                 "obu": 2,
#                 "0816": 2,
#                 "coto": 2,
#                 "static": 2,
#                 "Ozarka": 2,
#                 "0010": 2,
#                 "ozarka": 2,
#                 "1094": 2,
#                 "ozarks": 2,
#                 "Morrilton": 2,
#                 "uaccm": 2,
#                 "Petit": 2,
#                 "Jean": 2,
#                 "Philander": 2,
#                 "philander": 2,
#                 "pccua": 2,
#                 "seark": 2,
#                 "pcec": 2,
#                 "uaptc": 2,
#                 "Texarkana": 2,
#                 "uaht": 2,
#                 "uarichmountain": 2,
#                 "arkansas": 2,
#                 "Searcy": 2,
#                 "searcybeautycollege": 2,
#                 "shortercollege": 2,
#                 "51": 2,
#                 "1106": 2,
#                 "Williams": 2,
#                 "southark": 2,
#                 "saumag": 2,
#                 "sautech": 2,
#                 "Velvatex": 2,
#                 "velvatexcollege": 2,
#                 "94105": 2,
#                 "academyart": 2,
#                 "Chinese": 2,
#                 "94612": 2,
#                 "acchs": 2,
#                 "Radio": 2,
#                 "TV": 2,
#                 "Broadcasting": 2,
#                 "92647": 2,
#                 "94501": 2,
#                 "alameda": 2,
#                 "Allan": 2,
#                 "Hancock": 2,
#                 "93454": 2,
#                 "aada": 2,
#                 "absw": 2,
#                 "1625": 2,
#                 "91790": 2,
#                 "americanbeautycollege": 2,
#                 "americancareercollege": 2,
#                 "Theater": 2,
#                 "94108": 2,
#                 "arc": 2,
#                 "Antelope": 2,
#                 "1604": 2,
#                 "atcla": 2,
#                 "atcsd": 2,
#                 "Azusa": 2,
#                 "apu": 2,
#                 "buc": 2,
#                 "Biola": 2,
#                 "biola": 2,
#                 "Brownson": 2,
#                 "brownson": 2,
#                 "Bryan": 2,
#                 "bryanuniversity": 2,
#                 "Butte": 2,
#                 "Integral": 2,
#                 "ciis": 2,
#                 "Cabrillo": 2,
#                 "calbaptist": 2,
#                 "cca": 2,
#                 "94102": 2,
#                 "uchastings": 2,
#                 "caltech": 2,
#                 "callutheran": 2,
#                 "Luis": 2,
#                 "Obispo": 2,
#                 "calpoly": 2,
#                 "Alliant": 2,
#                 "alliant": 2,
#                 "91768": 2,
#                 "cpp": 2,
#                 "Chico": 2,
#                 "Dominguez": 2,
#                 "fresnostate": 2,
#                 "fullerton": 2,
#                 "csueastbay": 2,
#                 "Northridge": 2,
#                 "1312": 2,
#                 "berkeley": 2,
#                 "pdf": 2,
#                 "ucdavis": 2,
#                 "uci": 2,
#                 "ucla": 2,
#                 "Student": 2,
#                 "ucr": 2,
#                 "ucsd": 2,
#                 "fas": 2,
#                 "ucsb": 2,
#                 "1011": 2,
#                 "ucsc": 2,
#                 "finaidcalc": 2,
#                 "Sofia": 2,
#                 "bigfuture": 2,
#                 "calbeautycollege": 2,
#                 "calchristiancollege": 2,
#                 "calcoast": 2,
#                 "chdaschools": 2,
#                 "91355": 2,
#                 "2397": 2,
#                 "calarts": 2,
#                 "cwsl": 2,
#                 "Canada": 2,
#                 "Canyons": 2,
#                 "canyons": 2,
#                 "Casa": 2,
#                 "casalomacollege": 2,
#                 "Centro": 2,
#                 "115": 2,
#                 "Colton": 2,
#                 "Watsonville": 2,
#                 "Salinas": 2,
#                 "93906": 2,
#                 "Cerritos": 2,
#                 "Cerro": 2,
#                 "Coso": 2,
#                 "Chabot": 2,
#                 "94545": 2,
#                 "Chaffey": 2,
#                 "chaffey": 2,
#                 "Chapman": 2,
#                 "chapman": 2,
#                 "R": 2,
#                 "Drew": 2,
#                 "cdrewu": 2,
#                 "cui": 2,
#                 "68": 2,
#                 "Church": 2,
#                 "Divinity": 2,
#                 "cdsp": 2,
#                 "cgu": 2,
#                 "McKenna": 2,
#                 "Milan": 2,
#                 "93277": 2,
#                 "milaninstitute": 2,
#                 "Clovis": 2,
#                 "Adult": 2,
#                 "Coastline": 2,
#                 "cogswell": 2,
#                 "Coba": 2,
#                 "coba": 2,
#                 "westernu": 2,
#                 "columbiacollege": 2,
#                 "Compton": 2,
#                 "Contra": 2,
#                 "Costa": 2,
#                 "1799": 2,
#                 "Cuesta": 2,
#                 "Cuyamaca": 2,
#                 "92019": 2,
#                 "Cypress": 2,
#                 "5897": 2,
#                 "cypresscollege": 2,
#                 "De": 2,
#                 "Anza": 2,
#                 "92260": 2,
#                 "btyschool": 2,
#                 "tution": 2,
#                 "Dell": 2,
#                 "Arte": 2,
#                 "Physical": 2,
#                 "dellarte": 2,
#                 "123": 2,
#                 "disd": 2,
#                 "94523": 2,
#                 "dominican": 2,
#                 "Philosophy": 2,
#                 "dspt": 2,
#                 "Albert": 2,
#                 "Camino": 2,
#                 "ECC": 2,
#                 "Elegance": 2,
#                 "ei": 2,
#                 "Emperor": 2,
#                 "Traditional": 2,
#                 "95403": 2,
#                 "empcol": 2,
#                 "Evergreen": 2,
#                 "90015": 2,
#                 "Federico": 2,
#                 "federico": 2,
#                 "fielding": 2,
#                 "Branches": 2,
#                 "fivebranches": 2,
#                 "Redondo": 2,
#                 "rbbeautycollege": 2,
#                 "Foothill": 2,
#                 "Franciscan": 2,
#                 "fst": 2,
#                 "Fredrick": 2,
#                 "95501": 2,
#                 "fandcbeauty": 2,
#                 "1200": 2,
#                 "Fuller": 2,
#                 "fuller": 2,
#                 "78": 2,
#                 "Gavilan": 2,
#                 "gavilan": 2,
#                 "Gemological": 2,
#                 "Carlsbad": 2,
#                 "gia": 2,
#                 "ecamp": 2,
#                 "nwc": 2,
#                 "dba": 2,
#                 "Gate": 2,
#                 "ggu": 2,
#                 "GTU": 2,
#                 "Grossmont": 2,
#                 "92506": 2,
#                 "1209": 2,
#                 "Hartnell": 2,
#                 "hmc": 2,
#                 "Hilltop": 2,
#                 "hilltopbeautyschool": 2,
#                 "94619": 2,
#                 "hnu": 2,
#                 "Pacifica": 2,
#                 "pacifica": 2,
#                 "Humboldt": 2,
#                 "humboldt": 2,
#                 "Humphreys": 2,
#                 "Stockton": 2,
#                 "Campuses": 2,
#                 "humphreys": 2,
#                 "Imperial": 2,
#                 "imperial": 2,
#                 "ibt": 2,
#                 "Interior": 2,
#                 "Designers": 2,
#                 "idi": 2,
#                 "Toni": 2,
#                 "Guy": 2,
#                 "90401": 2,
#                 "toniguy": 2,
#                 "jfku": 2,
#                 "Jewish": 2,
#                 "1519": 2,
#                 "aju": 2,
#                 "Reedley": 2,
#                 "3298": 2,
#                 "lifepacific": 2,
#                 "4401": 2,
#                 "laverne": 2,
#                 "Laguna": 2,
#                 "lcad": 2,
#                 "Tahoe": 2,
#                 "Lancaster": 2,
#                 "lancasterbeautyschool": 2,
#                 "Laney": 2,
#                 "laney": 2,
#                 "Lassen": 2,
#                 "lifewest": 2,
#                 "6975": 2,
#                 "lincolnuca": 2,
#                 "socalsem": 2,
#                 "lasierra": 2,
#                 "Linda": 2,
#                 "llu": 2,
#                 "1706": 2,
#                 "1229": 2,
#                 "scuhs": 2,
#                 "4899": 2,
#                 "Trade": 2,
#                 "lattc": 2,
#                 "need": 2,
#                 "1220": 2,
#                 "Master": 2,
#                 "lacitycollege": 2,
#                 "Allied": 2,
#                 "portal": 2,
#                 "4195": 2,
#                 "90045": 2,
#                 "lmu": 2,
#                 "Lu": 2,
#                 "Ross": 2,
#                 "lurossacademy": 2,
#                 "Lyles": 2,
#                 "Lytles": 2,
#                 "Redwood": 2,
#                 "lytlesrebc": 2,
#                 "mtistockton": 2,
#                 "mticollege": 2,
#                 "Marin": 2,
#                 "2590": 2,
#                 "marin": 2,
#                 "marymountcalifornia": 2,
#                 "Mendocino": 2,
#                 "menlo": 2,
#                 "MiraCosta": 2,
#                 "Modern": 2,
#                 "modernbeautyacademy": 2,
#                 "95350": 2,
#                 "Moler": 2,
#                 "94609": 2,
#                 "moler": 2,
#                 "Middlebury": 2,
#                 "93940": 2,
#                 "middlebury": 2,
#                 "Peninsula": 2,
#                 "mpc": 2,
#                 "Moorpark": 2,
#                 "moorparkcollege": 2,
#                 "Antonio": 2,
#                 "1399": 2,
#                 "mtsac": 2,
#                 "SAC": 2,
#                 "Mount": 2,
#                 "msmu": 2,
#                 "academics": 2,
#                 "2399": 2,
#                 "msjc": 2,
#                 "StudentServices": 2,
#                 "CCD": 2,
#                 "Musicians": 2,
#                 "mi": 2,
#                 "disclosure": 2,
#                 "Napa": 2,
#                 "Holistic": 2,
#                 "nhi": 2,
#                 "Naval": 2,
#                 "Postgraduate": 2,
#                 "nps": 2,
#                 "Newschool": 2,
#                 "newschoolarch": 2,
#                 "Newberry": 2,
#                 "newberryschoolofbeauty": 2,
#                 "adrians": 2,
#                 "Covina": 2,
#                 "Notre": 2,
#                 "Dame": 2,
#                 "Namur": 2,
#                 "ndnu": 2,
#                 "Occidental": 2,
#                 "oxy": 2,
#                 "Ohlone": 2,
#                 "92626": 2,
#                 "Parsons": 2,
#                 "Oxnard": 2,
#                 "oxnardcollege": 2,
#                 "student_services": 2,
#                 "hiu": 2,
#                 "san": 2,
#                 "Alto": 2,
#                 "1255": 2,
#                 "pacificoaks": 2,
#                 "Religion": 2,
#                 "psr": 2,
#                 "90010": 2,
#                 "psuca": 2,
#                 "puc": 2,
#                 "pacific": 2,
#                 "Verde": 2,
#                 "Palomar": 2,
#                 "1487": 2,
#                 "pepperdine": 2,
#                 "pitzer": 2,
#                 "platt": 2,
#                 "2899": 2,
#                 "pointloma": 2,
#                 "pomona": 2,
#                 "1268": 2,
#                 "Porterville": 2,
#                 "pib": 2,
#                 "Ana": 2,
#                 "Pardee": 2,
#                 "RAND": 2,
#                 "prgs": 2,
#                 "shastaschoolofcosmetology": 2,
#                 "Redlands": 2,
#                 "redlands": 2,
#                 "Redwoods": 2,
#                 "redwoods": 2,
#                 "Upland": 2,
#                 "Corona": 2,
#                 "Hondo": 2,
#                 "90601": 2,
#                 "1616": 2,
#                 "riohondo": 2,
#                 "Rosemead": 2,
#                 "1639": 2,
#                 "ipeds": 2,
#                 "Dongguk": 2,
# ...
#                 "1657": 1,
#                 "60515": 1,
#                 "5514": 1,
#                 "midwestern": 1,
#                 "828115": 1,
#                 "998342": 1,
#                 "21553": 1,
#                 "60654": 1,
#                 "888293": 1,
#                 "63379": 1,
#                 "1694": 1,
#                 "718446": 1,
#                 "609384": 1,
#                 "1661": 1,
#                 "785701": 1,
#                 "591178": 1,
#                 "1774": 1,
#                 "UCHICAGO": 1,
#                 "collegeadmissions": 1,
#                 "uchicago": 1,
#                 "calculate": 1,
#                 "787994": 1,
#                 "599539": 1,
#                 "1654": 1,
#                 "60621": 1,
#                 "2709": 1,
#                 "780253": 1,
#                 "643425": 1,
#                 "1650": 1,
#                 "60612": 1,
#                 "878092": 1,
#                 "675321": 1,
#                 "9767": 1,
#                 "709997": 1,
#                 "589249": 1,
#                 "1648": 1,
#                 "60640": 1,
#                 "6063": 1,
#                 "964502": 1,
#                 "659107": 1,
#                 "1649": 1,
#                 "60652": 1,
#                 "755955": 1,
#                 "723981": 1,
#                 "1652": 1,
#                 "60601": 1,
#                 "2449": 1,
#                 "886067": 1,
#                 "626596": 1,
#                 "1655": 1,
#                 "60634": 1,
#                 "958774": 1,
#                 "787868": 1,
#                 "1665": 1,
#                 "1996": 1,
#                 "874261": 1,
#                 "624667": 1,
#                 "1666": 1,
#                 "60305": 1,
#                 "898696": 1,
#                 "809482": 1,
#                 "7549": 1,
#                 "3304": 1,
#                 "882558": 1,
#                 "627413": 1,
#                 "1669": 1,
#                 "5118": 1,
#                 "127539": 1,
#                 "587884": 1,
#                 "DACC": 1,
#                 "075809": 1,
#                 "636314": 1,
#                 "1671": 1,
#                 "877618": 1,
#                 "62724": 1,
#                 "21506": 1,
#                 "24918": 1,
#                 "294087": 1,
#                 "6656": 1,
#                 "60137": 1,
#                 "6599": 1,
#                 "consumer_legal_information": 1,
#                 "841577": 1,
#                 "071635": 1,
#                 "COD": 1,
#                 "21686": 1,
#                 "articles": 1,
#                 "871309": 1,
#                 "624793": 1,
#                 "1674": 1,
#                 "61920": 1,
#                 "479843": 1,
#                 "175658": 1,
#                 "EIU": 1,
#                 "E": 1,
#                 "1675": 1,
#                 "7193": 1,
#                 "018066": 1,
#                 "32194": 1,
#                 "1676": 1,
#                 "60126": 1,
#                 "3296": 1,
#                 "897164": 1,
#                 "945369": 1,
#                 "1678": 1,
#                 "61530": 1,
#                 "pricing": 1,
#                 "71482": 1,
#                 "269624": 1,
#                 "25849": 1,
#                 "FIRSTINSTITUTE": 1,
#                 "firstinstitute": 1,
#                 "21926": 1,
#                 "339468": 1,
#                 "25228": 1,
#                 "60638": 1,
#                 "771488": 1,
#                 "744728": 1,
#                 "1682": 1,
#                 "60201": 1,
#                 "056221": 1,
#                 "675497": 1,
#                 "4560": 1,
#                 "926394": 1,
#                 "404218": 1,
#                 "9145": 1,
#                 "60484": 1,
#                 "449103": 1,
#                 "716441": 1,
#                 "GSU": 1,
#                 "61520": 1,
#                 "2497": 1,
#                 "grahamschoolofnursing": 1,
#                 "grahamhealthsystem": 1,
#                 "department": 1,
#                 "552962": 1,
#                 "038776": 1,
#                 "1684": 1,
#                 "62246": 1,
#                 "894162": 1,
#                 "40824": 1,
#                 "22612": 1,
#                 "60195": 1,
#                 "gbeautyinstitutes": 1,
#                 "gskinbeautyinstitute": 1,
#                 "netprice18wd": 1,
#                 "061983": 1,
#                 "083218": 1,
#                 "23322": 1,
#                 "60178": 1,
#                 "962221": 1,
#                 "718145": 1,
#                 "22621": 1,
#                 "60543": 1,
#                 "682591": 1,
#                 "364727": 1,
#                 "1685": 1,
#                 "60077": 1,
#                 "component": 1,
#                 "k2": 1,
#                 "item": 1,
#                 "211": 1,
#                 "010103": 1,
#                 "760874": 1,
#                 "HTC": 1,
#                 "TI": 1,
#                 "Skokie": 1,
#                 "Blitstein": 1,
#                 "Machon": 1,
#                 "Torani": 1,
#                 "Banot": 1,
#                 "Beis": 1,
#                 "HaMidrash": 1,
#                 "Torah": 1,
#                 "1681": 1,
#                 "61032": 1,
#                 "9341": 1,
#                 "283344": 1,
#                 "67342": 1,
#                 "1659": 1,
#                 "60064": 1,
#                 "3095": 1,
#                 "rosalindfranklin": 1,
#                 "300069": 1,
#                 "859632": 1,
#                 "RFUMS": 1,
#                 "1776": 1,
#                 "60607": 1,
#                 "871837": 1,
#                 "650503": 1,
#                 "UIC": 1,
#                 "1767": 1,
#                 "0900": 1,
#                 "777569": 1,
#                 "097307": 1,
#                 "1689": 1,
#                 "3878": 1,
#                 "ICO": 1,
#                 "ico": 1,
#                 "835447": 1,
#                 "623016": 1,
#                 "1775": 1,
#                 "61820": 1,
#                 "5711": 1,
#                 "104718": 1,
#                 "229114": 1,
#                 "Illinios": 1,
#                 "Ilinois": 1,
#                 "Ilinios": 1,
#                 "UIUC": 1,
#                 "UICU": 1,
#                 "61702": 1,
#                 "2900": 1,
#                 "iwu": 1,
#                 "r1k4e0bodv0zsdap0m5xszxz": 1,
#                 "20Wesleyan": 1,
#                 "489901": 1,
#                 "992014": 1,
#                 "IWU": 1,
#                 "6753": 1,
#                 "61635": 1,
#                 "707235": 1,
#                 "52485": 1,
#                 "ICC": 1,
#                 "1688": 1,
#                 "7313": 1,
#                 "246171": 1,
#                 "1742": 1,
#                 "62450": 1,
#                 "occ": 1,
#                 "files_user": 1,
#                 "FAID": 1,
#                 "735913": 1,
#                 "099589": 1,
#                 "1691": 1,
#                 "iit": 1,
#                 "8313": 1,
#                 "627321": 1,
#                 "1692": 1,
#                 "61790": 1,
#                 "509403": 1,
#                 "990058": 1,
#                 "1705": 1,
#                 "61348": 1,
#                 "9692": 1,
#                 "30744": 1,
#                 "100887": 1,
#                 "IVCC": 1,
#                 "25737": 1,
#                 "876064": 1,
#                 "627217": 1,
#                 "8076": 1,
#                 "62918": 1,
#                 "747453": 1,
#                 "09021": 1,
#                 "jd": 1,
#                 "877966": 1,
#                 "628567": 1,
#                 "JMLS": 1,
#                 "12813": 1,
#                 "8736": 1,
#                 "913741": 1,
#                 "335828": 1,
#                 "60431": 1,
#                 "www3": 1,
#                 "500535": 1,
#                 "180985": 1,
#                 "1700": 1,
#                 "1498": 1,
#                 "061754": 1,
#                 "291336": 1,
#                 "7690": 1,
#                 "60901": 1,
#                 "fedstateaid": 1,
#                 "nccalc": 1,
#                 "098178": 1,
#                 "851047": 1,
#                 "62801": 1,
#                 "562112": 1,
#                 "191974": 1,
#                 "7684": 1,
#                 "60150": 1,
#                 "9699": 1,
#                 "938234": 1,
#                 "880524": 1,
#                 "9999": 1,
#                 "knox": 1,
#                 "KnoxCollege": 1,
#                 "943064": 1,
#                 "373165": 1,
#                 "9475": 1,
#                 "61354": 1,
#                 "1450": 1,
#                 "affordability": 1,
#                 "354338": 1,
#                 "118454": 1,
#                 "STERLING": 1,
#                 "SCHOOL": 1,
#                 "BEAUTY": 1,
#                 "CULTURE": 1,
#                 "INC": 1,
#                 "7694": 1,
#                 "60030": 1,
#                 "1198": 1,
#                 "CLCILLINOIS": 1,
#                 "clcillinois": 1,
#                 "354164": 1,
#                 "012291": 1,
#                 "249574": 1,
#                 "827454": 1,
#                 "23192": 1,
#                 "243432": 1,
#                 "893204": 1,
#                 "7644": 1,
#                 "61938": 1,
#                 "ss": 1,
#                 "fa": 1,
#                 "416969": 1,
#                 "380835": 1,
#                 "10501": 1,
#                 "fa_payment": 1,
#                 "13855": 1,
#                 "644379": 1,
#                 "10020": 1,
#                 "62035": 1,
#                 "951624": 1,
#                 "194405": 1,
#                 "1707": 1,
#                 "60446": 1,
#                 "2200": 1,
#                 "scholarshipcalculator": 1,
#                 "605432": 1,
#                 "079032": 1,
#                 "1708": 1,
#                 "2111": 1,
#                 "148924": 1,
#                 "346721": 1,
#                 "1709": 1,
#                 "155442": 1,
#                 "36153": 1,
#                 "7170": 1,
#                 "62794": 1,
#                 "9256": 1,
#                 "ww3": 1,
#                 "721211": 1,
#                 "611249": 1,
#                 "LLCC": 1,
#                 "60160": 1,
#                 "melrose": 1,
#                 "park": 1,
#                 "il": 1,
#                 "905577": 1,
#                 "832162": 1,
#                 "1710": 1,
#                 "60660": 1,
#                 "tuitionandfinancialaid": 1,
#                 "000765": 1,
#                 "656872": 1,
#                 "1712": 1,
#                 "5134": 1,
#                 "79563": 1,
#                 "598978": 1,
#                 "LSTC": 1,
#                 "6225": 1,
#                 "5317": 1,
#                 "484924": 1,
#                 "568862": 1,
#                 "22281": 1,
#                 "60657": 1,
#                 "courses": 1,
#                 "939685": 1,
#                 "657152": 1,
#                 "steven": 1,
#                 "papageorge": 1,
#                 "hair": 1,
#                 "1716": 1,
#                 "maccormac": 1,
#                 "ferrum": 1,
#                 "netPrice": 1,
#                 "881898": 1,
#                 "626657": 1,
#                 "730918": 1,
#                 "223986": 1,
#                 "1721": 1,
#                 "79597": 1,
#                 "598511": 1,
#                 "7691": 1,
#                 "60012": 1,
#                 "2761": 1,
#                 "259111": 1,
#                 "368956": 1,
#                 "MCC": 1,
#                 "McHenrey": 1,
#                 "1722": 1,
#                 "62254": 1,
#                 "608154": 1,
#                 "816822": 1,
#                 "1723": 1,
#                 "874027": 1,
#                 "624619": 1,
#                 "6228": 1,
#                 "61615": 1,
#                 "7804": 1,
#                 "682864": 1,
#                 "4568": 1,
#                 "61614": 1,
#                 "3595": 1,
#                 "761916": 1,
#                 "598859": 1,
#                 "1724": 1,
#                 "62522": 1,
#                 "2084": 1,
#                 "affordMU": 1,
#                 "842612": 1,
#                 "976298": 1,
#                 "1725": 1,
#                 "61462": 1,
#                 "1998": 1,
#                 "ou": 1,
#                 "914824": 1,
#                 "63731": 1,
#                 "1727": 1,
#                 "60610": 1,
#                 "3284": 1,
#                 "siteassets": 1,
#                 "website_assets": 1,
#                 "chicago": 1,
#                 "897822": 1,
#                 "633459": 1,
#                 "Michigan": 1,
#                 "Spokane": 1,
#                 "7692": 1,
#                 "60465": 1,
#                 "0937": 1,
#                 "694613": 1,
#                 "836915": 1,
#                 "MVCC": 1,
#                 "8880": 1,
#                 "61270": 1,
#                 "2959": 1,
#                 "netpricecalculator2": 1,
#                 "7971": 1,
#                 "965963": 1,
#                 "1728": 1,
#                 "60804": 1,
#                 "4398": 1,
#                 "824303": 1,
#                 "762306": 1,
#                 "21924": 1,
#                 "Calc": 1,
#                 "846081": 1,
#                 "933574": 1,
#                 "1733": 1,
#                 "880093": 1,
#                 "624699": 1,
#                 "1732": 1,
#                 "60148": 1,
#                 "4583": 1,
#                 "assistance": 1,
#                 "861697": 1,
#                 "013171": 1,
#                 "25566": 1,
#                 "60714": 1,
#                 "027601": 1,
#                 "815113": 1,
#                 "1734": 1,
#                 "60540": 1,
#                 "77576": 1,
#                 "14279": 1,
#                 "NCC": 1,
#                 "Cardinals": 1,
#                 "1735": 1,
#                 "4895": 1,
#                 "Undergraduate": 1,
#                 "975268": 1,
#                 "709948": 1,
#                 "1736": 1,
#                 "809104": 1,
#                 "056162": 1,
#                 "1737": 1,
#                 "60115": 1,
#                 "2828": 1,
#                 "bursar": 1,
#                 "933869": 1,
#                 "766428": 1,
#                 "1739": 1,
#                 "60208": 1,
#                 "050356": 1,
#                 "679858": 1,
#                 "1693": 1,
#                 "4699": 1,
#                 "980399": 1,
#                 "718983": 1,
#                 "9896": 1,
#                 "60016": 1,
#                 "061893": 1,
#                 "880644": 1,
#                 "22975": 1,
#                 "61611": 1,
#                 "665832": 1,
#                 "55712": 1,
#                 "1741": 1,
#                 "2271": 1,
#                 "155237": 1,
#                 "875165": 1,
#                 "7118": 1,
#                 "61821": 1,
#                 "131963": 1,
#                 "290359": 1,
#                 "1640": 1,
#                 "60411": 1,
#                 "8226": 1,
#                 "reg": 1,
#                 "525316": 1,
#                 "638943": 1,
#                 "1744": 1,
#                 "62028": 1,
#                 "9799": 1,
#                 "948835": 1,
#                 "350285": 1,
#                 "23233": 1,
#                 "60435": 1,
#                 "523122": 1,
#                 "148846": 1,
#                 "1745": 1,
#                 "2699": 1,
#                 "938898": 1,
#                 "385975": 1,
#                 "7119": 1,
#                 "62846": 1,
#                 "131481": 1,
#                 "918283": 1,
#                 "10879": 1,
#                 "8512": 1,
#                 "system": 1,
#                 "883887": 1,
#                 "894125": 1,
#                 "1746": 1,
#                 "876278": 1,
#                 "627068": 1,
#                 "RMC": 1,
#                 "RMU": 1,
#                 "1747": 1,
#                 "61114": 1,
#                 "306174": 1,
#                 "993544": 1,
#                 "10913": 1,
#                 "255723": 1,
#                 "02722": 1,
#                 "1748": 1,
#                 "2311": 1,
#                 "rockford": 1,
#                 "270639": 1,
#                 "019536": 1
#             },
#             "times": {
#                 "vocab": 0.0065,
#                 "words": 0.0252
#             }
#         }
#     }
# }

# %% [markdown]
# ## Profiler options

# %% [markdown]
# The DataProfiler has the ability to turn on and off components as needed. This is accomplished via the `ProfilerOptions` class.
#
# For example, if a user doesn't require vocab count information they may desire to turn off the word count functionality.
#
# Below, let's remove the vocab count and set the stop words.
#
# Full list of options in the Profiler section of the [DataProfiler documentation](https://capitalone.github.io/DataProfiler).

# %%
data = dp.Data(os.path.join(data_path, "txt/discussion_reddit.txt"))

profile_options = dp.ProfilerOptions()

# Set multiple options at the same time via set
profile_options.set({ "vocab.is_enabled": False })

# Set options via directly setting them
profile_options.unstructured_options.text.stop_words = ["These", "are", "stop", "words"]

profile = dp.Profiler(data, options=profile_options)
report  = profile.report(report_options={"output_format": "compact"})

# Print the report
print(json.dumps(report, indent=4))

# %% [markdown]
# ## Updating Profiles

# %% [markdown]
# Beyond just profiling, one of the unique aspects of the DataProfiler is the ability to update the profiles. To update appropriately, the schema (columns / keys) must match appropriately.

# %%
# Load and profile a CSV file
data = dp.Data(os.path.join(data_path, "txt/sentence-3x.txt"))
profile = dp.Profiler(data)

# Update the profile with new data:
new_data = dp.Data(os.path.join(data_path, "txt/sentence-3x.txt"))
profile.update_profile(new_data)

# Take a peek at the data
print(data.data)
print(new_data.data)

# Report the compact version of the profile
report  = profile.report(report_options={"output_format": "compact"})
print(json.dumps(report, indent=4))

# %% [markdown]
# ## Merging Profiles

# %% [markdown]
# Merging profiles are an alternative method for updating profiles. Particularly, multiple profiles can be generated seperately, then added together with a simple `+` command: `profile3 = profile1 + profile2`

# %%
# Load a CSV file with a schema
data1 = dp.Data(os.path.join(data_path, "txt/sentence-3x.txt"))
profile1 = dp.Profiler(data1)

# Load another CSV file with the same schema
data2 = dp.Data(os.path.join(data_path, "txt/sentence-3x.txt"))
profile2 = dp.Profiler(data2)

# Merge the profiles
profile3 = profile1 + profile2

# Report the compact version of the profile
report  = profile3.report(report_options={"output_format":"compact"})
print(json.dumps(report, indent=4))

# %% [markdown]
# As you can see, the `update_profile` function and the `+` operator function similarly. The reason the `+` operator is important is that it's possible to *save and load profiles*, which we cover next.

# %% [markdown]
# ## Saving and Loading a Profile

# %% [markdown]
# Not only can the Profiler create and update profiles, it's also possible to save, load then manipulate profiles.

# %%
# Load data
data = dp.Data(os.path.join(data_path, "txt/sentence-3x.txt"))

# Generate a profile
profile = dp.Profiler(data)

# Save a profile to disk for later (saves as pickle file)
profile.save(filepath="my_profile.pkl")

# Load a profile from disk
loaded_profile = dp.Profiler.load("my_profile.pkl")

# Report the compact version of the profile
report = profile.report(report_options={"output_format":"compact"})
print(json.dumps(report, indent=4))

# %% [markdown]
# With the ability to save and load profiles, profiles can be generated via multiple machines then merged. Further, profiles can be stored and later used in applications such as change point detection, synthetic data generation, and more.

# %%
# Load a multiple files via the Data class
filenames = ["txt/sentence-3x.txt",
             "txt/sentence.txt"]
data_objects = []
for filename in filenames:
    data_objects.append(dp.Data(os.path.join(data_path, filename)))

print(data_objects)
# Generate and save profiles
for i in range(len(data_objects)):
    profile = dp.Profiler(data_objects[i])
    report = profile.report(report_options={"output_format":"compact"})
    print(json.dumps(report, indent=4))
    profile.save(filepath="data-"+str(i)+".pkl")


# Load profiles and add them together
profile = None
for i in range(len(data_objects)):
    if profile is None:
        profile = dp.Profiler.load("data-"+str(i)+".pkl")
    else:
        profile += dp.Profiler.load("data-"+str(i)+".pkl")


# Report the compact version of the profile
report = profile.report(report_options={"output_format":"compact"})
print(json.dumps(report, indent=4))
